# %% [markdown]
# <a href="https://colab.research.google.com/github/evansalv/social-perception-convo/blob/main/Semantic_Preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Step 1: Enable rpy2 and upload transcript CSV
# %load_ext rpy2.ipython

import pandas as pd
import numpy as np
from rpy2.robjects import pandas2ri
pandas2ri.activate()
import rpy2.robjects as ro
import os
import sys
from rpy2.robjects import r, globalenv, StrVector
from scipy.spatial import distance
import re
import inflect

p = inflect.engine()

# %%
# Step 2: Set up transcriptions
# Change this path to where semantic helper code are stored
sem_dir  = '/content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/'
# Add the semantic directory to sys.path
sys.path.append(sem_dir)
# Output path for semantic data
transcript_dir = '/content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Studies/Study2/'
output_dir = '/content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/Outputs/'

# %%
from BERT_helper import bert_embedding

# %%
# Define full paths to the files
transcript_path = os.path.join(transcript_dir, 'transcript.csv')
#word_level_path = os.path.join(video_dir, 'Observer_Segments_WordData.xlsx')

# Load the datasets
transcript = pd.read_csv(transcript_path)

# %%
print("\nWord-level transcription loaded:")
print(transcript.head())
# Out:
# Word-level transcription loaded:
#   Transcript Start_Timestamp End_Timestamp    Speaker  Pair  Question  \
# 0       What     00:00:00:04   00:00:00:21  Speaker 1     1         2
# 1         in     00:00:00:21   00:00:00:28  Speaker 1     1         2
# 2       your     00:00:00:28   00:00:00:37  Speaker 1     1         2
# 3       life     00:00:00:37   00:00:00:49  Speaker 1     1         2
# 4         do     00:00:00:49   00:00:00:57  Speaker 1     1         2
#
#    Start_Seconds  End_Seconds  Speaker_Displayed      VideoID  turnID  \
# 0           0.04         0.21                  1  3YxFNCQJXz0       1
# 1           0.21         0.28                  1  3YxFNCQJXz0       1
# 2           0.28         0.37                  1  3YxFNCQJXz0       1
# 3           0.37         0.49                  1  3YxFNCQJXz0       1
# 4           0.49         0.57                  1  3YxFNCQJXz0       1
#
#    turnSpeaker1  turnSpeaker2  turnIDSpeaker1  turnIDSpeaker2 2segIDSpeaker1  \
# 0             1             0             1.0             NaN        T1_SEG1
# 1             1             0             1.0             NaN        T1_SEG1
# 2             1             0             1.0             NaN        T1_SEG1
# 3             1             0             1.0             NaN        T1_SEG1
# 4             1             0             1.0             NaN        T1_SEG1
#
#   2segIDSpeaker2 5segIDSpeaker1 5segIDSpeaker2
# 0            NaN        T1_SEG1            NaN
# 1            NaN        T1_SEG1            NaN
# 2            NaN        T1_SEG1            NaN
# 3            NaN        T1_SEG1            NaN
# 4            NaN        T1_SEG1            NaN

# %%
# Helper functions:

# Convert number: replace the number string to the word of the number ('4' -> 'four')
def replace_numbers(match):
            return p.number_to_words(match.group())

# Clean text: clean text for dictionary word embeddings (AffectR, wav2vec, GloVe, etc.)

def clean_text(text):
    """
    Cleans transcript text from a DataFrame column for word embedding.

    Parameters:
    - df: pandas DataFrame containing the text
    - column: name of the column with text to clean
    - convert_numbers: whether to convert numeric tokens to words (e.g., '4' → 'four')

    Returns:
    - cleaned string
    """

    # Make all lowercase
    text.lower()

    # Replace numbers with words if specified
    text = re.sub(r'\d+', replace_numbers, text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text)

    return text

# %%
# Install AffectR
# %%
# %%R
# Install devtools if it's not already installed
if (!requireNamespace("devtools", quietly = TRUE)) {
  install.packages("devtools")
}
# Install the affectr package from GitHub
devtools::install_github("markallenthornton/affectr")
# Out:
# Skipping install of 'affectr' from a github remote, the SHA1 (d6727a81) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
# Load R package
r('library(affectr)')

# Output list
results = []
total_vids = len(transcript['VideoID'].unique())
vid_count = 0
# Iterate over each VideoID and turn
for vid in transcript['VideoID'].unique():
    vid_count += 1
    print(f"\n📽️ Processing Video {vid_count} / {total_vids} → VideoID: {vid}")

    vid_data = transcript[transcript['VideoID'] == vid]

    for turn in vid_data['turnID'].dropna().unique():
        turn_data = vid_data[vid_data['turnID'] == turn]

        for speaker in ['Speaker 1', 'Speaker 2']:
            listener = 'Speaker 2' if speaker == 'Speaker 1' else 'Speaker 1'
            active_flag = f'5segID{speaker.replace(" ", "")}'

            if active_flag not in turn_data.columns:
                continue

            seg_ids = turn_data[active_flag].dropna().unique()
            if len(seg_ids) == 0:
                continue

            for seg in seg_ids:
                seg_data = turn_data[turn_data[active_flag] == seg]
                text = ' '.join(seg_data['Transcript'].astype(str)).strip()
                cleaned_text = clean_text(text)
                # Defaults
                affect_scores = [0.0, 0.0, 0.0]
                bert_embed = [0.0] * 1024

                # If speaker is talking and text exists
                if text:
                    try:
                        # Compute affectr
                        globalenv['texts'] = StrVector([cleaned_text])
                        r('scores <- affect3d(texts[1])')
                        affect_scores = list(r('as.numeric(scores)'))

                        # Compute BERT
                        bert_embed = bert_embedding("FacebookAI/roberta-large-mnli", text)
                    except Exception as e:
                        print(f"⚠️ Processing failed for VideoID={vid}, Turn={turn}, Segment={seg}, Speaker={speaker}: {e}")
                        affect_scores = [0.0, 0.0, 0.0]
                        bert_embed = [0.0] * 1024

                # Unpack BERT embedding into 1024 columns
                embed_dict = {}
                if speaker == 'Speaker 1':
                    for i in range(1024):
                        embed_dict[f'BERT_Spkr1_{i}'] = bert_embed[i]
                        embed_dict[f'BERT_Spkr2_{i}'] = 0.0
                else:
                    for i in range(1024):
                        embed_dict[f'BERT_Spkr1_{i}'] = 0.0
                        embed_dict[f'BERT_Spkr2_{i}'] = bert_embed[i]

                # Record results
                results.append({
                    'VideoID': vid,
                    'Transcript': text,
                    'Clean_Transcript': cleaned_text,
                    'turnID': turn,
                    '5segIDSpeaker1':	seg if speaker == 'Speaker 1' else np.nan,
                    '5segIDSpeaker2': seg if speaker == 'Speaker 2' else np.nan,
                    'Speaker': speaker,
                    'Listener': listener,
                    'rationality_Spkr1': affect_scores[0] if speaker == 'Speaker 1' else 0,
                    'social_impact_Spkr1': affect_scores[1] if speaker == 'Speaker 1' else 0,
                    'valence_Spkr1': affect_scores[2] if speaker == 'Speaker 1' else 0,
                    'rationality_Spkr2': affect_scores[0] if speaker == 'Speaker 2' else 0,
                    'social_impact_Spkr2': affect_scores[1] if speaker == 'Speaker 2' else 0,
                    'valence_Spkr2': affect_scores[2] if speaker == 'Speaker 2' else 0,
                    **embed_dict
                })

                print(f"✅ Processed → VideoID: {vid}, TurnID: {int(turn)}, Speaker: {speaker}, Segment: {seg}")

# Convert to DataFrame
word_embeddings = pd.DataFrame(results)

# Preview the shape and first few rows
print(f"\n Final output shape: {word_embeddings.shape}")
word_embeddings.head()
# Out:
# 📽️ Processing Video 1 / 46 → VideoID: 3YxFNCQJXz0
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG2
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG3
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG4
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG5
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG6
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 12, Speaker: Speaker 2, Segment: T12_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 13, Speaker: Speaker 1, Segment: T13_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 14, Speaker: Speaker 2, Segment: T14_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 15, Speaker: Speaker 1, Segment: T15_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 18, Speaker: Speaker 2, Segment: T18_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 22, Speaker: Speaker 2, Segment: T22_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 23, Speaker: Speaker 1, Segment: T23_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 24, Speaker: Speaker 2, Segment: T24_SEG1
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 24, Speaker: Speaker 2, Segment: T24_SEG2
# ✅ Processed → VideoID: 3YxFNCQJXz0, TurnID: 25, Speaker: Speaker 1, Segment: T25_SEG1
#
# 📽️ Processing Video 2 / 46 → VideoID: 4SOtva6huN8
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG2
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG3
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG4
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG5
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG6
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG7
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG8
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG9
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG10
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG11
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: 4SOtva6huN8, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
#
# 📽️ Processing Video 3 / 46 → VideoID: ZIUxkzM48sg
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG2
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG2
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG3
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG4
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: ZIUxkzM48sg, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
#
# 📽️ Processing Video 4 / 46 → VideoID: Wq3NHuI7SvE
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG2
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG3
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG4
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG2
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG3
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: Wq3NHuI7SvE, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
#
# 📽️ Processing Video 5 / 46 → VideoID: oufrU7mdSGw
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG2
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 11, Speaker: Speaker 2, Segment: T11_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 12, Speaker: Speaker 1, Segment: T12_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 13, Speaker: Speaker 2, Segment: T13_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 14, Speaker: Speaker 1, Segment: T14_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 15, Speaker: Speaker 2, Segment: T15_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 16, Speaker: Speaker 1, Segment: T16_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 17, Speaker: Speaker 2, Segment: T17_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 18, Speaker: Speaker 1, Segment: T18_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 19, Speaker: Speaker 2, Segment: T19_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 20, Speaker: Speaker 1, Segment: T20_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 21, Speaker: Speaker 2, Segment: T21_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 22, Speaker: Speaker 1, Segment: T22_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 24, Speaker: Speaker 1, Segment: T24_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 25, Speaker: Speaker 2, Segment: T25_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 26, Speaker: Speaker 1, Segment: T26_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 27, Speaker: Speaker 2, Segment: T27_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 28, Speaker: Speaker 1, Segment: T28_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 29, Speaker: Speaker 2, Segment: T29_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 30, Speaker: Speaker 1, Segment: T30_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 31, Speaker: Speaker 2, Segment: T31_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 32, Speaker: Speaker 1, Segment: T32_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 33, Speaker: Speaker 2, Segment: T33_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 34, Speaker: Speaker 1, Segment: T34_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 35, Speaker: Speaker 2, Segment: T35_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 36, Speaker: Speaker 1, Segment: T36_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 37, Speaker: Speaker 2, Segment: T37_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 38, Speaker: Speaker 1, Segment: T38_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 39, Speaker: Speaker 2, Segment: T39_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 40, Speaker: Speaker 1, Segment: T40_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 41, Speaker: Speaker 2, Segment: T41_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 42, Speaker: Speaker 1, Segment: T42_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 43, Speaker: Speaker 2, Segment: T43_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 44, Speaker: Speaker 1, Segment: T44_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 45, Speaker: Speaker 2, Segment: T45_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 46, Speaker: Speaker 1, Segment: T46_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 47, Speaker: Speaker 2, Segment: T47_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 48, Speaker: Speaker 1, Segment: T48_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 49, Speaker: Speaker 2, Segment: T49_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 50, Speaker: Speaker 1, Segment: T50_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 51, Speaker: Speaker 2, Segment: T51_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 52, Speaker: Speaker 1, Segment: T52_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 53, Speaker: Speaker 2, Segment: T53_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 54, Speaker: Speaker 1, Segment: T54_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 55, Speaker: Speaker 2, Segment: T55_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 56, Speaker: Speaker 1, Segment: T56_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 57, Speaker: Speaker 2, Segment: T57_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 58, Speaker: Speaker 1, Segment: T58_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 59, Speaker: Speaker 2, Segment: T59_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 60, Speaker: Speaker 1, Segment: T60_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 61, Speaker: Speaker 2, Segment: T61_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 62, Speaker: Speaker 1, Segment: T62_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 63, Speaker: Speaker 2, Segment: T63_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 64, Speaker: Speaker 1, Segment: T64_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 65, Speaker: Speaker 2, Segment: T65_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 66, Speaker: Speaker 1, Segment: T66_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 67, Speaker: Speaker 2, Segment: T67_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 68, Speaker: Speaker 1, Segment: T68_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 69, Speaker: Speaker 2, Segment: T69_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 70, Speaker: Speaker 1, Segment: T70_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 71, Speaker: Speaker 2, Segment: T71_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 72, Speaker: Speaker 1, Segment: T72_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 73, Speaker: Speaker 2, Segment: T73_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 74, Speaker: Speaker 1, Segment: T74_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 75, Speaker: Speaker 2, Segment: T75_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 76, Speaker: Speaker 1, Segment: T76_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 77, Speaker: Speaker 2, Segment: T77_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 78, Speaker: Speaker 1, Segment: T78_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 79, Speaker: Speaker 2, Segment: T79_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 80, Speaker: Speaker 1, Segment: T80_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 81, Speaker: Speaker 2, Segment: T81_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 82, Speaker: Speaker 1, Segment: T82_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 83, Speaker: Speaker 2, Segment: T83_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 84, Speaker: Speaker 1, Segment: T84_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 85, Speaker: Speaker 2, Segment: T85_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 86, Speaker: Speaker 1, Segment: T86_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 87, Speaker: Speaker 2, Segment: T87_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 88, Speaker: Speaker 1, Segment: T88_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 89, Speaker: Speaker 2, Segment: T89_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 90, Speaker: Speaker 1, Segment: T90_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 91, Speaker: Speaker 2, Segment: T91_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 92, Speaker: Speaker 1, Segment: T92_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 93, Speaker: Speaker 2, Segment: T93_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 94, Speaker: Speaker 1, Segment: T94_SEG1
# ✅ Processed → VideoID: oufrU7mdSGw, TurnID: 95, Speaker: Speaker 2, Segment: T95_SEG1
#
# 📽️ Processing Video 6 / 46 → VideoID: Ze1sDAx62JQ
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 11, Speaker: Speaker 2, Segment: T11_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 12, Speaker: Speaker 1, Segment: T12_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 13, Speaker: Speaker 2, Segment: T13_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 14, Speaker: Speaker 1, Segment: T14_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 15, Speaker: Speaker 2, Segment: T15_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 16, Speaker: Speaker 1, Segment: T16_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 17, Speaker: Speaker 2, Segment: T17_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 18, Speaker: Speaker 1, Segment: T18_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 19, Speaker: Speaker 2, Segment: T19_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 20, Speaker: Speaker 1, Segment: T20_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 21, Speaker: Speaker 2, Segment: T21_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 22, Speaker: Speaker 1, Segment: T22_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 24, Speaker: Speaker 1, Segment: T24_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 25, Speaker: Speaker 2, Segment: T25_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 26, Speaker: Speaker 1, Segment: T26_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 27, Speaker: Speaker 2, Segment: T27_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 28, Speaker: Speaker 1, Segment: T28_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 29, Speaker: Speaker 2, Segment: T29_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 30, Speaker: Speaker 1, Segment: T30_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 31, Speaker: Speaker 2, Segment: T31_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 32, Speaker: Speaker 1, Segment: T32_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 33, Speaker: Speaker 2, Segment: T33_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 34, Speaker: Speaker 1, Segment: T34_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 35, Speaker: Speaker 2, Segment: T35_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 36, Speaker: Speaker 1, Segment: T36_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 37, Speaker: Speaker 2, Segment: T37_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 38, Speaker: Speaker 1, Segment: T38_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 39, Speaker: Speaker 2, Segment: T39_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 40, Speaker: Speaker 1, Segment: T40_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 41, Speaker: Speaker 2, Segment: T41_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 42, Speaker: Speaker 1, Segment: T42_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 43, Speaker: Speaker 2, Segment: T43_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 44, Speaker: Speaker 1, Segment: T44_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 45, Speaker: Speaker 2, Segment: T45_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 46, Speaker: Speaker 1, Segment: T46_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 47, Speaker: Speaker 2, Segment: T47_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 48, Speaker: Speaker 1, Segment: T48_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 49, Speaker: Speaker 2, Segment: T49_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 50, Speaker: Speaker 1, Segment: T50_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 51, Speaker: Speaker 2, Segment: T51_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 52, Speaker: Speaker 1, Segment: T52_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 53, Speaker: Speaker 2, Segment: T53_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 54, Speaker: Speaker 1, Segment: T54_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 55, Speaker: Speaker 2, Segment: T55_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 56, Speaker: Speaker 1, Segment: T56_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 57, Speaker: Speaker 2, Segment: T57_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 58, Speaker: Speaker 1, Segment: T58_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 59, Speaker: Speaker 2, Segment: T59_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 60, Speaker: Speaker 1, Segment: T60_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 61, Speaker: Speaker 2, Segment: T61_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 62, Speaker: Speaker 1, Segment: T62_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 64, Speaker: Speaker 1, Segment: T64_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 63, Speaker: Speaker 2, Segment: T63_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 65, Speaker: Speaker 2, Segment: T65_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 66, Speaker: Speaker 1, Segment: T66_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 67, Speaker: Speaker 2, Segment: T67_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 68, Speaker: Speaker 1, Segment: T68_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 69, Speaker: Speaker 2, Segment: T69_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 70, Speaker: Speaker 1, Segment: T70_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 71, Speaker: Speaker 2, Segment: T71_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 72, Speaker: Speaker 1, Segment: T72_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 73, Speaker: Speaker 2, Segment: T73_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 74, Speaker: Speaker 1, Segment: T74_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 75, Speaker: Speaker 2, Segment: T75_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 76, Speaker: Speaker 1, Segment: T76_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 77, Speaker: Speaker 2, Segment: T77_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 78, Speaker: Speaker 1, Segment: T78_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 79, Speaker: Speaker 2, Segment: T79_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 80, Speaker: Speaker 1, Segment: T80_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 81, Speaker: Speaker 2, Segment: T81_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 82, Speaker: Speaker 1, Segment: T82_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 83, Speaker: Speaker 2, Segment: T83_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 84, Speaker: Speaker 1, Segment: T84_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 85, Speaker: Speaker 2, Segment: T85_SEG1
# ✅ Processed → VideoID: Ze1sDAx62JQ, TurnID: 86, Speaker: Speaker 1, Segment: T86_SEG1
#
# 📽️ Processing Video 7 / 46 → VideoID: D1nKXipBejs
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 12, Speaker: Speaker 2, Segment: T12_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 13, Speaker: Speaker 1, Segment: T13_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 14, Speaker: Speaker 2, Segment: T14_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 15, Speaker: Speaker 1, Segment: T15_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG2
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 18, Speaker: Speaker 2, Segment: T18_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 22, Speaker: Speaker 2, Segment: T22_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 23, Speaker: Speaker 1, Segment: T23_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 24, Speaker: Speaker 2, Segment: T24_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 25, Speaker: Speaker 1, Segment: T25_SEG1
# ✅ Processed → VideoID: D1nKXipBejs, TurnID: 26, Speaker: Speaker 2, Segment: T26_SEG1
#
# 📽️ Processing Video 8 / 46 → VideoID: j61RprE_mMM
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG2
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG2
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG3
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG4
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG5
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: j61RprE_mMM, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
#
# 📽️ Processing Video 9 / 46 → VideoID: 7KQFhsWAkhw
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG2
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG3
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG4
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG5
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 11, Speaker: Speaker 2, Segment: T11_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 12, Speaker: Speaker 1, Segment: T12_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 13, Speaker: Speaker 2, Segment: T13_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 14, Speaker: Speaker 1, Segment: T14_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 15, Speaker: Speaker 2, Segment: T15_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 16, Speaker: Speaker 1, Segment: T16_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 17, Speaker: Speaker 2, Segment: T17_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 18, Speaker: Speaker 1, Segment: T18_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 19, Speaker: Speaker 2, Segment: T19_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 20, Speaker: Speaker 1, Segment: T20_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 20, Speaker: Speaker 1, Segment: T20_SEG2
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 21, Speaker: Speaker 2, Segment: T21_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 22, Speaker: Speaker 1, Segment: T22_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG1
# ✅ Processed → VideoID: 7KQFhsWAkhw, TurnID: 24, Speaker: Speaker 1, Segment: T24_SEG1
#
# 📽️ Processing Video 10 / 46 → VideoID: GG02S5v_kXA
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG2
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG3
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG4
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG5
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG6
# ✅ Processed → VideoID: GG02S5v_kXA, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
#
# 📽️ Processing Video 11 / 46 → VideoID: llqqND5shG8
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG2
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG3
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG4
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG5
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG2
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG3
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG4
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG5
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG6
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG7
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG8
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG9
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG10
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG11
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG12
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG13
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG14
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG2
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG3
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG4
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG5
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG6
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG7
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG8
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG9
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG10
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG11
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG12
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG13
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG14
# ✅ Processed → VideoID: llqqND5shG8, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
#
# 📽️ Processing Video 12 / 46 → VideoID: MokxWYOEudM
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG2
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG2
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG2
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG3
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG2
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG3
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG4
# ✅ Processed → VideoID: MokxWYOEudM, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG5
#
# 📽️ Processing Video 13 / 46 → VideoID: w7f7baovc_Y
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG2
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 12, Speaker: Speaker 2, Segment: T12_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 13, Speaker: Speaker 1, Segment: T13_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 14, Speaker: Speaker 2, Segment: T14_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 15, Speaker: Speaker 1, Segment: T15_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 18, Speaker: Speaker 2, Segment: T18_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG2
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG1
# ✅ Processed → VideoID: w7f7baovc_Y, TurnID: 22, Speaker: Speaker 2, Segment: T22_SEG1
#
# 📽️ Processing Video 14 / 46 → VideoID: yaJcfRNzzzs
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG2
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG2
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG3
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG2
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 11, Speaker: Speaker 2, Segment: T11_SEG1
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 11, Speaker: Speaker 2, Segment: T11_SEG2
# ✅ Processed → VideoID: yaJcfRNzzzs, TurnID: 12, Speaker: Speaker 1, Segment: T12_SEG1
#
# 📽️ Processing Video 15 / 46 → VideoID: qYUbcQokhVo
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG3
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG4
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG5
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG3
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 11, Speaker: Speaker 2, Segment: T11_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 12, Speaker: Speaker 1, Segment: T12_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 13, Speaker: Speaker 2, Segment: T13_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 14, Speaker: Speaker 1, Segment: T14_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 15, Speaker: Speaker 2, Segment: T15_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 16, Speaker: Speaker 1, Segment: T16_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 17, Speaker: Speaker 2, Segment: T17_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 17, Speaker: Speaker 2, Segment: T17_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 18, Speaker: Speaker 1, Segment: T18_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 19, Speaker: Speaker 2, Segment: T19_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 20, Speaker: Speaker 1, Segment: T20_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 21, Speaker: Speaker 2, Segment: T21_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 21, Speaker: Speaker 2, Segment: T21_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 22, Speaker: Speaker 1, Segment: T22_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG2
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG3
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 23, Speaker: Speaker 2, Segment: T23_SEG4
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 24, Speaker: Speaker 1, Segment: T24_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 25, Speaker: Speaker 2, Segment: T25_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 26, Speaker: Speaker 1, Segment: T26_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 27, Speaker: Speaker 2, Segment: T27_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 28, Speaker: Speaker 1, Segment: T28_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 29, Speaker: Speaker 2, Segment: T29_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 30, Speaker: Speaker 1, Segment: T30_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 31, Speaker: Speaker 2, Segment: T31_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 32, Speaker: Speaker 1, Segment: T32_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 33, Speaker: Speaker 2, Segment: T33_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 34, Speaker: Speaker 1, Segment: T34_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 35, Speaker: Speaker 2, Segment: T35_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 36, Speaker: Speaker 1, Segment: T36_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 37, Speaker: Speaker 2, Segment: T37_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 38, Speaker: Speaker 1, Segment: T38_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 39, Speaker: Speaker 2, Segment: T39_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 40, Speaker: Speaker 1, Segment: T40_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 41, Speaker: Speaker 2, Segment: T41_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 42, Speaker: Speaker 1, Segment: T42_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 43, Speaker: Speaker 2, Segment: T43_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 44, Speaker: Speaker 1, Segment: T44_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 45, Speaker: Speaker 2, Segment: T45_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 46, Speaker: Speaker 1, Segment: T46_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 47, Speaker: Speaker 2, Segment: T47_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 48, Speaker: Speaker 1, Segment: T48_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 49, Speaker: Speaker 2, Segment: T49_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 50, Speaker: Speaker 1, Segment: T50_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 51, Speaker: Speaker 2, Segment: T51_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 52, Speaker: Speaker 1, Segment: T52_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 53, Speaker: Speaker 2, Segment: T53_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 54, Speaker: Speaker 1, Segment: T54_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 55, Speaker: Speaker 2, Segment: T55_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 56, Speaker: Speaker 1, Segment: T56_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 57, Speaker: Speaker 2, Segment: T57_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 58, Speaker: Speaker 1, Segment: T58_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 59, Speaker: Speaker 2, Segment: T59_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 60, Speaker: Speaker 1, Segment: T60_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 61, Speaker: Speaker 2, Segment: T61_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 62, Speaker: Speaker 1, Segment: T62_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 63, Speaker: Speaker 2, Segment: T63_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 64, Speaker: Speaker 1, Segment: T64_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 65, Speaker: Speaker 2, Segment: T65_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 66, Speaker: Speaker 1, Segment: T66_SEG1
# ✅ Processed → VideoID: qYUbcQokhVo, TurnID: 67, Speaker: Speaker 2, Segment: T67_SEG1
#
# 📽️ Processing Video 16 / 46 → VideoID: XP1g9LcplB8
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 12, Speaker: Speaker 2, Segment: T12_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 13, Speaker: Speaker 1, Segment: T13_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 14, Speaker: Speaker 2, Segment: T14_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 15, Speaker: Speaker 1, Segment: T15_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG2
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG3
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 18, Speaker: Speaker 2, Segment: T18_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG2
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG2
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG3
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 22, Speaker: Speaker 2, Segment: T22_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 23, Speaker: Speaker 1, Segment: T23_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 24, Speaker: Speaker 2, Segment: T24_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 25, Speaker: Speaker 1, Segment: T25_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 26, Speaker: Speaker 2, Segment: T26_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 27, Speaker: Speaker 1, Segment: T27_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 28, Speaker: Speaker 2, Segment: T28_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 29, Speaker: Speaker 1, Segment: T29_SEG1
# ✅ Processed → VideoID: XP1g9LcplB8, TurnID: 30, Speaker: Speaker 2, Segment: T30_SEG1
#
# 📽️ Processing Video 17 / 46 → VideoID: yVo1bFCQfv0
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG3
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG3
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 12, Speaker: Speaker 2, Segment: T12_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 13, Speaker: Speaker 1, Segment: T13_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 14, Speaker: Speaker 2, Segment: T14_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 15, Speaker: Speaker 1, Segment: T15_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 18, Speaker: Speaker 2, Segment: T18_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 22, Speaker: Speaker 2, Segment: T22_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 23, Speaker: Speaker 1, Segment: T23_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 23, Speaker: Speaker 1, Segment: T23_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 24, Speaker: Speaker 2, Segment: T24_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 25, Speaker: Speaker 1, Segment: T25_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 26, Speaker: Speaker 2, Segment: T26_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 27, Speaker: Speaker 1, Segment: T27_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 28, Speaker: Speaker 2, Segment: T28_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 29, Speaker: Speaker 1, Segment: T29_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 30, Speaker: Speaker 2, Segment: T30_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 31, Speaker: Speaker 1, Segment: T31_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 32, Speaker: Speaker 2, Segment: T32_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 32, Speaker: Speaker 2, Segment: T32_SEG2
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 33, Speaker: Speaker 1, Segment: T33_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 34, Speaker: Speaker 2, Segment: T34_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 35, Speaker: Speaker 1, Segment: T35_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 36, Speaker: Speaker 2, Segment: T36_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 37, Speaker: Speaker 1, Segment: T37_SEG1
# ✅ Processed → VideoID: yVo1bFCQfv0, TurnID: 38, Speaker: Speaker 2, Segment: T38_SEG1
#
# 📽️ Processing Video 18 / 46 → VideoID: _D77faGnzxw
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG2
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG3
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG4
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG2
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG3
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 9, Speaker: Speaker 2, Segment: T9_SEG1
# ✅ Processed → VideoID: _D77faGnzxw, TurnID: 10, Speaker: Speaker 1, Segment: T10_SEG1
#
# 📽️ Processing Video 19 / 46 → VideoID: qrWNXJyiop4
# ✅ Processed → VideoID: qrWNXJyiop4, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: qrWNXJyiop4, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG2
# ✅ Processed → VideoID: qrWNXJyiop4, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG3
# ✅ Processed → VideoID: qrWNXJyiop4, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG4
# ✅ Processed → VideoID: qrWNXJyiop4, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG5
# ✅ Processed → VideoID: qrWNXJyiop4, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
#
# 📽️ Processing Video 20 / 46 → VideoID: iMPrFwaLp9M
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 1, Speaker: Speaker 1, Segment: T1_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 2, Speaker: Speaker 2, Segment: T2_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 3, Speaker: Speaker 1, Segment: T3_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 4, Speaker: Speaker 2, Segment: T4_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 5, Speaker: Speaker 1, Segment: T5_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 6, Speaker: Speaker 2, Segment: T6_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 7, Speaker: Speaker 1, Segment: T7_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 8, Speaker: Speaker 2, Segment: T8_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 9, Speaker: Speaker 1, Segment: T9_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 10, Speaker: Speaker 2, Segment: T10_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 11, Speaker: Speaker 1, Segment: T11_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 12, Speaker: Speaker 2, Segment: T12_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 13, Speaker: Speaker 1, Segment: T13_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 14, Speaker: Speaker 2, Segment: T14_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 15, Speaker: Speaker 1, Segment: T15_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 16, Speaker: Speaker 2, Segment: T16_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 17, Speaker: Speaker 1, Segment: T17_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 18, Speaker: Speaker 2, Segment: T18_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 19, Speaker: Speaker 1, Segment: T19_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 20, Speaker: Speaker 2, Segment: T20_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 21, Speaker: Speaker 1, Segment: T21_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 22, Speaker: Speaker 2, Segment: T22_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 23, Speaker: Speaker 1, Segment: T23_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 24, Speaker: Speaker 2, Segment: T24_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 25, Speaker: Speaker 1, Segment: T25_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 26, Speaker: Speaker 2, Segment: T26_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 27, Speaker: Speaker 1, Segment: T27_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 28, Speaker: Speaker 2, Segment: T28_SEG1
# ✅ Processed → VideoID: iMPrFwaLp9M, TurnID: 29, Speaker: Speaker 1, Segment: T29_SEG1
#
# 📽️ Processing Video 21 / 46 → VideoID: jwuI--2-X8A
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 1, Speaker: Speaker 2, Segment: T1_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 2, Speaker: Speaker 1, Segment: T2_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 3, Speaker: Speaker 2, Segment: T3_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 4, Speaker: Speaker 1, Segment: T4_SEG2
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 5, Speaker: Speaker 2, Segment: T5_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 6, Speaker: Speaker 1, Segment: T6_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 7, Speaker: Speaker 2, Segment: T7_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG1
# ✅ Processed → VideoID: jwuI--2-X8A, TurnID: 8, Speaker: Speaker 1, Segment: T8_SEG2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-599614155> in <cell line: 0>()
#      44
#      45                         # Compute BERT
# ---> 46                         bert_embed = bert_embedding("FacebookAI/roberta-large-mnli", text)
#      47                     except Exception as e:
#      48                         print(f"⚠️ Processing failed for VideoID={vid}, Turn={turn}, Segment={seg}, Speaker={speaker}: {e}")
#
# /content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/BERT_helper.py in bert_embedding(model_name, text)
#      48 # Main wrapper function for R to call
#      49 def bert_embedding(model_name, text):
# ---> 50     return embed_model(model_name, text)
#      51
#      52 # Minimal test indicator
#
# /content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/BERT_helper.py in embed_model(model_type, text)
#      29         model = DebertaV2Model.from_pretrained("microsoft/deberta-v2-xxlarge")
#      30     elif 'FacebookAI/roberta-large-mnli' in model_type:
# ---> 31         tokenizer = RobertaTokenizer.from_pretrained("FacebookAI/roberta-large-mnli")
#      32         model = RobertaModel.from_pretrained("FacebookAI/roberta-large-mnli")
#      33     elif 'microsoft/deberta-xlarge' in model_type:
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2023                 logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
#    2024
# -> 2025         return cls._from_pretrained(
#    2026             resolved_vocab_files,
#    2027             pretrained_model_name_or_path,
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in _from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2276         # Instantiate the tokenizer.
#    2277         try:
# -> 2278             tokenizer = cls(*init_inputs, **init_kwargs)
#    2279         except import_protobuf_decode_error():
#    2280             logger.info(
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/roberta/tokenization_roberta.py in __init__(self, vocab_file, merges_file, errors, bos_token, eos_token, sep_token, cls_token, unk_token, pad_token, mask_token, add_prefix_space, **kwargs)
#     186
#     187         with open(vocab_file, encoding="utf-8") as vocab_handle:
# --> 188             self.encoder = json.load(vocab_handle)
#     189         self.decoder = {v: k for k, v in self.encoder.items()}
#     190         self.errors = errors  # how to handle errors in decoding
#
# /usr/lib/python3.11/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.11/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
# Columns to check for NaNs
columns_to_check = [
    'rationality_Spkr1', 'social_impact_Spkr1', 'valence_Spkr1',
    'rationality_Spkr2', 'social_impact_Spkr2', 'valence_Spkr2'
]

# Check for NaNs in any of the specified columns
has_nan = word_embeddings[columns_to_check].isna().any()

# Print which columns contain NaNs
print("🔍 NaN Check:")
print(has_nan)

# Optionally, show rows where any of those columns have NaN
rows_with_nan = word_embeddings[word_embeddings[columns_to_check].isna().any(axis=1)]
print(f"\n⚠️ Total rows with NaNs in these columns: {len(rows_with_nan)}")
rows_with_nan
# Out:
# 🔍 NaN Check:
# rationality_Spkr1      False
# social_impact_Spkr1    False
# valence_Spkr1          False
# rationality_Spkr2      False
# social_impact_Spkr2    False
# valence_Spkr2          False
# dtype: bool
#
# ⚠️ Total rows with NaNs in these columns: 0
# Empty DataFrame
# Columns: [VideoID, Transcript, Clean_Transcript, turnID, 5segIDSpeaker1, 5segIDSpeaker2, Speaker, Listener, rationality_Spkr1, social_impact_Spkr1, valence_Spkr1, rationality_Spkr2, social_impact_Spkr2, valence_Spkr2, BERT_Spkr1_0, BERT_Spkr2_0, BERT_Spkr1_1, BERT_Spkr2_1, BERT_Spkr1_2, BERT_Spkr2_2, BERT_Spkr1_3, BERT_Spkr2_3, BERT_Spkr1_4, BERT_Spkr2_4, BERT_Spkr1_5, BERT_Spkr2_5, BERT_Spkr1_6, BERT_Spkr2_6, BERT_Spkr1_7, BERT_Spkr2_7, BERT_Spkr1_8, BERT_Spkr2_8, BERT_Spkr1_9, BERT_Spkr2_9, BERT_Spkr1_10, BERT_Spkr2_10, BERT_Spkr1_11, BERT_Spkr2_11, BERT_Spkr1_12, BERT_Spkr2_12, BERT_Spkr1_13, BERT_Spkr2_13, BERT_Spkr1_14, BERT_Spkr2_14, BERT_Spkr1_15, BERT_Spkr2_15, BERT_Spkr1_16, BERT_Spkr2_16, BERT_Spkr1_17, BERT_Spkr2_17, BERT_Spkr1_18, BERT_Spkr2_18, BERT_Spkr1_19, BERT_Spkr2_19, BERT_Spkr1_20, BERT_Spkr2_20, BERT_Spkr1_21, BERT_Spkr2_21, BERT_Spkr1_22, BERT_Spkr2_22, BERT_Spkr1_23, BERT_Spkr2_23, BERT_Spkr1_24, BERT_Spkr2_24, BERT_Spkr1_25, BERT_Spkr2_25, BERT_Spkr1_26, BERT_Spkr2_26, BERT_Spkr1_27, BERT_Spkr2_27, BERT_Spkr1_28, BERT_Spkr2_28, BERT_Spkr1_29, BERT_Spkr2_29, BERT_Spkr1_30, BERT_Spkr2_30, BERT_Spkr1_31, BERT_Spkr2_31, BERT_Spkr1_32, BERT_Spkr2_32, BERT_Spkr1_33, BERT_Spkr2_33, BERT_Spkr1_34, BERT_Spkr2_34, BERT_Spkr1_35, BERT_Spkr2_35, BERT_Spkr1_36, BERT_Spkr2_36, BERT_Spkr1_37, BERT_Spkr2_37, BERT_Spkr1_38, BERT_Spkr2_38, BERT_Spkr1_39, BERT_Spkr2_39, BERT_Spkr1_40, BERT_Spkr2_40, BERT_Spkr1_41, BERT_Spkr2_41, BERT_Spkr1_42, BERT_Spkr2_42, ...]
# Index: []
#
# [0 rows x 2062 columns]

# %%
# Define the output file path
output_path = output_dir + 'word_embeddings.csv'

# Save the DataFrame to CSV
word_embeddings.to_csv(output_path, index=False)

print(f"✅ CSV file successfully saved to: {output_path}")
# Out:
# ✅ CSV file successfully saved to: /content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/Outputs/word_embeddings.csv

# %%
output_path = output_dir + 'word_embeddings.csv'
word_embeddings = pd.read_csv(output_path)

# %%
# Compute distance meaures for Affect3D word embeddings

# Step 1: Mean-pooling affectR vector
def mean_pool_affectr_vector(group, speaker):
    """Extract and mean-pool affectR values for the active speaker."""
    if speaker == 'Speaker 1':
        rationality = group['rationality_Spkr1']
        social_impact = group['social_impact_Spkr1']
        valence = group['valence_Spkr1']
    else:
        rationality = group['rationality_Spkr2']
        social_impact = group['social_impact_Spkr2']
        valence = group['valence_Spkr2']

    matrix = np.stack([rationality, social_impact, valence], axis=1)
    return matrix.mean(axis=0) if len(matrix) > 1 else matrix[0]

# Step 2: Compute Euclidean distances for each affect dimension
def compute_euclidean_distances(turn_vectors):
    """Compute Euclidean distances between consecutive turns for each dimension."""
    valence_dist, social_impact_dist, rationality_dist = [np.nan], [np.nan], [np.nan]

    for i in range(1, len(turn_vectors)):
        v1, v2 = turn_vectors[i - 1], turn_vectors[i]
        rationality_dist.append(distance.euclidean([v1[0]], [v2[0]]))
        social_impact_dist.append(distance.euclidean([v1[1]], [v2[1]]))
        valence_dist.append(distance.euclidean([v1[2]], [v2[2]]))

    return rationality_dist, social_impact_dist, valence_dist

# Step 3: Main function to compute Mahalanobis + Euclidean distances
def compute_affectr_distances(df):
    """Compute Mahalanobis and Euclidean distances for affectR vectors by turn and VideoID."""
    results = []

    for vid in df['VideoID'].unique():
        print(f"\n📼 Processing VideoID: {vid}")
        vid_data = df[df['VideoID'] == vid]
        grouped = vid_data.groupby('turnID')

        turn_vectors = []
        turn_ids = []
        speakers = []

        for turn_id, group in grouped:
            speaker = group['Speaker'].iloc[0]
            vector = mean_pool_affectr_vector(group, speaker)

            print(f"\n🎬 TurnID: {turn_id}")
            print(f"   🗣️ Active Speaker: {speaker}")
            print(f"   ✅ Mean-pooled AffectR vector: {vector}")

            turn_vectors.append(vector)
            turn_ids.append(turn_id)
            speakers.append(speaker)

        # Step 3a: Mahalanobis distances
        cov = np.cov(np.stack(turn_vectors).T)
        inv_covmat = np.linalg.pinv(cov)
        maha_dists = [np.nan]
        for i in range(1, len(turn_vectors)):
            d = distance.mahalanobis(turn_vectors[i], turn_vectors[i - 1], inv_covmat)
            maha_dists.append(d)
            print(f"📏 Mahalanobis distance between Turn {turn_ids[i - 1]} and Turn {turn_ids[i]}: {d}")

        # Step 3b: Euclidean distances
        rationality_euc, social_euc, valence_euc = compute_euclidean_distances(turn_vectors)

        # Step 4: Save DataFrame
        results_df = pd.DataFrame({
            'VideoID': [vid] * len(turn_ids),
            'turnID': turn_ids,
            'Speaker': speakers,
            '3D_Dist': maha_dists,
            'Rationality_Dist': rationality_euc,
            'Social_Impact_Dist': social_euc,
            'Valence_Dist': valence_euc
        })

        results.append(results_df)

    return pd.concat(results, ignore_index=True)

# Step 5: Apply to your word_embeddings data
affectR_dist = compute_affectr_distances(word_embeddings)

# Step 6: Inspect result
print(f"\n✅ Final output shape of distance measurement: {affectR_dist.shape}")
affectR_dist.head()
# Out:
# Streaming output truncated to the last 5000 lines.
#    ✅ Mean-pooled AffectR vector: [0.95304143 0.14159757 0.22041   ]
#
# 🎬 TurnID: 104
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.89273354 -0.19064277  0.08991877]
#
# 🎬 TurnID: 105
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.64147439 -0.02664852 -0.04302597]
#
# 🎬 TurnID: 106
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.81272138 -0.12029763 -0.00490773]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 2.0132152394817493
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.502104957564272
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 2.407924105626881
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 1.4462572112230156
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 1.7103668989007967
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 1.352231747212943
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 1.432884357769352
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 0.9325969890631739
# 📏 Mahalanobis distance between Turn 9 and Turn 10: 3.1512548652036734
# 📏 Mahalanobis distance between Turn 10 and Turn 11: 3.0442779034124414
# 📏 Mahalanobis distance between Turn 11 and Turn 12: 4.580553939918728
# 📏 Mahalanobis distance between Turn 12 and Turn 13: 4.357799989646503
# 📏 Mahalanobis distance between Turn 13 and Turn 14: 1.0235879119592226
# 📏 Mahalanobis distance between Turn 14 and Turn 15: 2.2596645307335423
# 📏 Mahalanobis distance between Turn 15 and Turn 16: 6.107465767926217
# 📏 Mahalanobis distance between Turn 16 and Turn 17: 6.949118856322723
# 📏 Mahalanobis distance between Turn 17 and Turn 18: 5.767425429453014
# 📏 Mahalanobis distance between Turn 18 and Turn 19: 2.8978945217952092
# 📏 Mahalanobis distance between Turn 19 and Turn 20: 2.93396104743261
# 📏 Mahalanobis distance between Turn 20 and Turn 21: 1.547525764226764
# 📏 Mahalanobis distance between Turn 21 and Turn 22: 1.577953442295373
# 📏 Mahalanobis distance between Turn 22 and Turn 23: 1.2854871982314717
# 📏 Mahalanobis distance between Turn 23 and Turn 24: 0.9855996980242495
# 📏 Mahalanobis distance between Turn 24 and Turn 25: 0.7628882644398314
# 📏 Mahalanobis distance between Turn 25 and Turn 26: 0.6085147029694066
# 📏 Mahalanobis distance between Turn 26 and Turn 27: 0.8609944911956203
# 📏 Mahalanobis distance between Turn 27 and Turn 28: 1.5784162140821185
# 📏 Mahalanobis distance between Turn 28 and Turn 29: 2.1460403880739234
# 📏 Mahalanobis distance between Turn 29 and Turn 30: 1.2629892840328945
# 📏 Mahalanobis distance between Turn 30 and Turn 31: 1.6296055487819503
# 📏 Mahalanobis distance between Turn 31 and Turn 32: 2.1038007127655987
# 📏 Mahalanobis distance between Turn 32 and Turn 33: 2.6371386674799773
# 📏 Mahalanobis distance between Turn 33 and Turn 34: 4.479449029820108
# 📏 Mahalanobis distance between Turn 34 and Turn 35: 3.9551912218552885
# 📏 Mahalanobis distance between Turn 35 and Turn 36: 4.017754108058835
# 📏 Mahalanobis distance between Turn 36 and Turn 37: 0.3922868243170825
# 📏 Mahalanobis distance between Turn 37 and Turn 38: 0.7057439424857689
# 📏 Mahalanobis distance between Turn 38 and Turn 39: 1.6378694658430666
# 📏 Mahalanobis distance between Turn 39 and Turn 40: 1.8761437200570605
# 📏 Mahalanobis distance between Turn 40 and Turn 41: 1.893510589194159
# 📏 Mahalanobis distance between Turn 41 and Turn 42: 1.9928508140871342
# 📏 Mahalanobis distance between Turn 42 and Turn 43: 1.3610759506034271
# 📏 Mahalanobis distance between Turn 43 and Turn 44: 1.0718488821346406
# 📏 Mahalanobis distance between Turn 44 and Turn 45: 0.9303293100338093
# 📏 Mahalanobis distance between Turn 45 and Turn 46: 1.6608253547254281
# 📏 Mahalanobis distance between Turn 46 and Turn 47: 1.6230253638981047
# 📏 Mahalanobis distance between Turn 47 and Turn 48: 1.5414398483381364
# 📏 Mahalanobis distance between Turn 48 and Turn 49: 4.996127772111585
# 📏 Mahalanobis distance between Turn 49 and Turn 50: 5.1139617730758005
# 📏 Mahalanobis distance between Turn 50 and Turn 51: 4.54172631954503
# 📏 Mahalanobis distance between Turn 51 and Turn 52: 2.1440750027881457
# 📏 Mahalanobis distance between Turn 52 and Turn 53: 2.29146040185337
# 📏 Mahalanobis distance between Turn 53 and Turn 54: 2.0388224331436553
# 📏 Mahalanobis distance between Turn 54 and Turn 55: 2.6855816667108754
# 📏 Mahalanobis distance between Turn 55 and Turn 56: 2.661666759521789
# 📏 Mahalanobis distance between Turn 56 and Turn 57: 0.3290433795037845
# 📏 Mahalanobis distance between Turn 57 and Turn 58: 0.424010975153821
# 📏 Mahalanobis distance between Turn 58 and Turn 59: 0.3495037367066311
# 📏 Mahalanobis distance between Turn 59 and Turn 60: 1.2092176647278359
# 📏 Mahalanobis distance between Turn 60 and Turn 61: 1.9637048352166853
# 📏 Mahalanobis distance between Turn 61 and Turn 62: 2.516122339915672
# 📏 Mahalanobis distance between Turn 62 and Turn 63: 1.6503112425144906
# 📏 Mahalanobis distance between Turn 63 and Turn 64: 2.0745562876628494
# 📏 Mahalanobis distance between Turn 64 and Turn 65: 1.8307728479533059
# 📏 Mahalanobis distance between Turn 65 and Turn 66: 5.7098300543977745
# 📏 Mahalanobis distance between Turn 66 and Turn 67: 2.6553157080840135
# 📏 Mahalanobis distance between Turn 67 and Turn 68: 2.410157861199753
# 📏 Mahalanobis distance between Turn 68 and Turn 69: 0.5011814971609655
# 📏 Mahalanobis distance between Turn 69 and Turn 70: 0.60471289703847
# 📏 Mahalanobis distance between Turn 70 and Turn 71: 0.6698553505873662
# 📏 Mahalanobis distance between Turn 71 and Turn 72: 1.2367200347303482
# 📏 Mahalanobis distance between Turn 72 and Turn 73: 1.5294012555193404
# 📏 Mahalanobis distance between Turn 73 and Turn 74: 2.116145927568972
# 📏 Mahalanobis distance between Turn 74 and Turn 75: 0.21013323248841048
# 📏 Mahalanobis distance between Turn 75 and Turn 76: 0.2741814658298483
# 📏 Mahalanobis distance between Turn 76 and Turn 77: 2.339234557166254
# 📏 Mahalanobis distance between Turn 77 and Turn 78: 1.590124793410368
# 📏 Mahalanobis distance between Turn 78 and Turn 79: 0.30219952458384686
# 📏 Mahalanobis distance between Turn 79 and Turn 80: 2.8196680596903487
# 📏 Mahalanobis distance between Turn 80 and Turn 81: 2.495799503944023
# 📏 Mahalanobis distance between Turn 81 and Turn 82: 1.3184452920344174
# 📏 Mahalanobis distance between Turn 82 and Turn 83: 2.872185898045905
# 📏 Mahalanobis distance between Turn 83 and Turn 84: 3.504527887126064
# 📏 Mahalanobis distance between Turn 84 and Turn 85: 0.6797594600306485
# 📏 Mahalanobis distance between Turn 85 and Turn 86: 0.534789926298417
# 📏 Mahalanobis distance between Turn 86 and Turn 87: 1.8671558146627796
# 📏 Mahalanobis distance between Turn 87 and Turn 88: 1.9668138444549934
# 📏 Mahalanobis distance between Turn 88 and Turn 89: 1.9668138444549934
# 📏 Mahalanobis distance between Turn 89 and Turn 90: 0.9761836958904946
# 📏 Mahalanobis distance between Turn 90 and Turn 91: 2.8415464557661467
# 📏 Mahalanobis distance between Turn 91 and Turn 92: 0.45484366626072126
# 📏 Mahalanobis distance between Turn 92 and Turn 93: 3.040093830369768
# 📏 Mahalanobis distance between Turn 93 and Turn 94: 2.82776847383594
# 📏 Mahalanobis distance between Turn 94 and Turn 95: 1.0817159028903924
# 📏 Mahalanobis distance between Turn 95 and Turn 96: 1.9902966528388735
# 📏 Mahalanobis distance between Turn 96 and Turn 97: 1.271001626088016
# 📏 Mahalanobis distance between Turn 97 and Turn 98: 1.0368728354029766
# 📏 Mahalanobis distance between Turn 98 and Turn 99: 2.197828249882018
# 📏 Mahalanobis distance between Turn 99 and Turn 100: 0.6359257743513625
# 📏 Mahalanobis distance between Turn 100 and Turn 101: 1.5351532870133688
# 📏 Mahalanobis distance between Turn 101 and Turn 102: 1.5087161924477908
# 📏 Mahalanobis distance between Turn 102 and Turn 103: 3.1667383292355735
# 📏 Mahalanobis distance between Turn 103 and Turn 104: 3.4802000512307165
# 📏 Mahalanobis distance between Turn 104 and Turn 105: 2.374014379930555
# 📏 Mahalanobis distance between Turn 105 and Turn 106: 1.1940305789018157
#
# 📼 Processing VideoID: s-djtoC8SjQ
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.89417656 -0.04941149  0.25036796]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.75133166 -0.04429643  0.12629582]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.03484131 -0.02157083  0.25976306]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.43727532 -0.27145891 -0.24000919]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.83147518 -0.0185454   0.12429604]
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.0883696   0.09131421 -0.05284302]
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.9085503  -0.03029438  0.13762316]
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.7510493  -0.11717109  0.06361137]
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.73570609 -0.02180985  0.21270126]
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.78126035 -0.01245746  0.11398554]
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.030006   -0.17527741  0.08683484]
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.80180468 0.05078347 0.10264802]
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.74124654 -0.00929814  0.11316722]
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.7343295  -0.15609414 -0.13706713]
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.77947434 -0.00318431  0.15026028]
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.5602264  0.15616429 0.17021445]
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.8592246  0.00532112 0.12136463]
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.8396995  -0.010917    0.14400443]
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.82282834 0.09640455 0.30155161]
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 29
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.11142783 -0.02338747  0.18631522]
#
# 🎬 TurnID: 30
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 31
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.9915259  0.0395515  0.29594225]
#
# 🎬 TurnID: 32
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 33
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.98498316 -0.11316822  0.14192179]
#
# 🎬 TurnID: 34
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 35
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.02108448 -0.23069381  0.10826925]
#
# 🎬 TurnID: 36
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.83954556 -0.05291958  0.02772051]
#
# 🎬 TurnID: 37
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.74412251 -0.14093155  0.5695961 ]
#
# 🎬 TurnID: 38
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.69165053 -0.14346998  0.28259515]
#
# 🎬 TurnID: 39
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 40
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.87291261 -0.14900997  0.05596596]
#
# 🎬 TurnID: 41
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 42
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.27324908 -0.02702255  0.07241787]
#
# 🎬 TurnID: 43
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 44
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.94810746 -0.03747215  0.16791889]
#
# 🎬 TurnID: 45
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 46
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [1.01440497 0.01971911 0.20659279]
#
# 🎬 TurnID: 47
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 48
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.74897635 0.03509755 0.08986124]
#
# 🎬 TurnID: 49
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 50
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.98139052 -0.02457043  0.15107281]
#
# 🎬 TurnID: 51
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76188003 -0.05244694  0.1351034 ]
#
# 🎬 TurnID: 52
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.84089214 -0.03138211  0.08501983]
#
# 🎬 TurnID: 53
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.58597891 -0.13648291  0.05584726]
#
# 🎬 TurnID: 54
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.65549639 0.08494209 0.32424958]
#
# 🎬 TurnID: 55
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.80370786 -0.11781877  0.23215179]
#
# 🎬 TurnID: 56
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.83365043 0.01324935 0.17433933]
#
# 🎬 TurnID: 57
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 58
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.79802867 -0.07473177  0.07261994]
#
# 🎬 TurnID: 59
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 60
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.06025052 -0.00564486  0.15263251]
#
# 🎬 TurnID: 61
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 62
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.62688782 0.0347135  0.15699287]
#
# 🎬 TurnID: 63
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.73677975 -0.08282104 -0.05231914]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 1.3292440174271836
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.2568787330954736
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 3.153268046595755
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 3.153268046595755
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 4.060737228167462
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 4.060737228167462
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 2.4399856736675427
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 3.0450474121598017
# 📏 Mahalanobis distance between Turn 9 and Turn 10: 3.1519992595287594
# 📏 Mahalanobis distance between Turn 10 and Turn 11: 1.8925253304454828
# 📏 Mahalanobis distance between Turn 11 and Turn 12: 0.7474166882935029
# 📏 Mahalanobis distance between Turn 12 and Turn 13: 1.0192253623703944
# 📏 Mahalanobis distance between Turn 13 and Turn 14: 1.010672820013554
# 📏 Mahalanobis distance between Turn 14 and Turn 15: 2.331774166759042
# 📏 Mahalanobis distance between Turn 15 and Turn 16: 3.246750277501798
# 📏 Mahalanobis distance between Turn 16 and Turn 17: 1.5898713070979364
# 📏 Mahalanobis distance between Turn 17 and Turn 18: 2.346325121199935
# 📏 Mahalanobis distance between Turn 18 and Turn 19: 2.6083552744226077
# 📏 Mahalanobis distance between Turn 19 and Turn 20: 2.236841038901509
# 📏 Mahalanobis distance between Turn 20 and Turn 21: 1.7495047838087248
# 📏 Mahalanobis distance between Turn 21 and Turn 22: 2.0669034567947544
# 📏 Mahalanobis distance between Turn 22 and Turn 23: 1.5924641322437023
# 📏 Mahalanobis distance between Turn 23 and Turn 24: 1.368128247384215
# 📏 Mahalanobis distance between Turn 24 and Turn 25: 2.5564599778515054
# 📏 Mahalanobis distance between Turn 25 and Turn 26: 2.4408268941178703
# 📏 Mahalanobis distance between Turn 26 and Turn 27: 1.0932319084730449
# 📏 Mahalanobis distance between Turn 27 and Turn 28: 2.8650168559025255
# 📏 Mahalanobis distance between Turn 28 and Turn 29: 2.701397835771213
# 📏 Mahalanobis distance between Turn 29 and Turn 30: 2.701397835771213
# 📏 Mahalanobis distance between Turn 30 and Turn 31: 3.0125367254209254
# 📏 Mahalanobis distance between Turn 31 and Turn 32: 3.971607730886766
# 📏 Mahalanobis distance between Turn 32 and Turn 33: 2.804395654544399
# 📏 Mahalanobis distance between Turn 33 and Turn 34: 1.800633718812864
# 📏 Mahalanobis distance between Turn 34 and Turn 35: 1.9437660207153988
# 📏 Mahalanobis distance between Turn 35 and Turn 36: 2.5549910024317355
# 📏 Mahalanobis distance between Turn 36 and Turn 37: 5.8173952669285685
# 📏 Mahalanobis distance between Turn 37 and Turn 38: 2.664454008980234
# 📏 Mahalanobis distance between Turn 38 and Turn 39: 2.630016030542367
# 📏 Mahalanobis distance between Turn 39 and Turn 40: 0.9392264473224817
# 📏 Mahalanobis distance between Turn 40 and Turn 41: 2.8263051153805763
# 📏 Mahalanobis distance between Turn 41 and Turn 42: 3.868631562409945
# 📏 Mahalanobis distance between Turn 42 and Turn 43: 3.868631562409945
# 📏 Mahalanobis distance between Turn 43 and Turn 44: 2.753836821883931
# 📏 Mahalanobis distance between Turn 44 and Turn 45: 2.0511563843168004
# 📏 Mahalanobis distance between Turn 45 and Turn 46: 2.6904320498659247
# 📏 Mahalanobis distance between Turn 46 and Turn 47: 3.656547782504548
# 📏 Mahalanobis distance between Turn 47 and Turn 48: 2.77999957671677
# 📏 Mahalanobis distance between Turn 48 and Turn 49: 2.4494980206349215
# 📏 Mahalanobis distance between Turn 49 and Turn 50: 2.848441790867041
# 📏 Mahalanobis distance between Turn 50 and Turn 51: 1.0172413954157888
# 📏 Mahalanobis distance between Turn 51 and Turn 52: 0.762212486579614
# 📏 Mahalanobis distance between Turn 52 and Turn 53: 1.8037526589483315
# 📏 Mahalanobis distance between Turn 53 and Turn 54: 2.2678542976279163
# 📏 Mahalanobis distance between Turn 54 and Turn 55: 1.7185883930353751
# 📏 Mahalanobis distance between Turn 55 and Turn 56: 2.0148874782623873
# 📏 Mahalanobis distance between Turn 56 and Turn 57: 2.412095335109553
# 📏 Mahalanobis distance between Turn 57 and Turn 58: 2.469697000723836
# 📏 Mahalanobis distance between Turn 58 and Turn 59: 1.1489119451559888
# 📏 Mahalanobis distance between Turn 59 and Turn 60: 2.570337390547985
# 📏 Mahalanobis distance between Turn 60 and Turn 61: 3.121153503781499
# 📏 Mahalanobis distance between Turn 61 and Turn 62: 1.8869790292992807
# 📏 Mahalanobis distance between Turn 62 and Turn 63: 1.2931405383036525
#
# 📼 Processing VideoID: mVRMa5MAqGo
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.85073166 -0.12909538  0.1025742 ]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.85128053 -0.02998695  0.13431789]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [1.1272757  0.03657908 0.10332493]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.81812515 -0.0798337   0.1233383 ]
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.92059493 -0.03196341  0.16224145]
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.93365955 -0.04794034  0.12046654]
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.01005984 -0.10887899  0.15567139]
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.96346519 -0.17195205  0.21538812]
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.72290793 -0.14692892  0.10014875]
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.03852772 -0.07096801  0.18541501]
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.94717328 0.01104522 0.24321217]
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.85644765 -0.06202651  0.24285297]
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.90999681 -0.06493356  0.20491112]
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.95476197 -0.01277686  0.16712978]
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 29
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.95840352 -0.0243088   0.23584152]
#
# 🎬 TurnID: 30
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 31
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.89693393 0.03847915 0.19004198]
#
# 🎬 TurnID: 32
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.82213003 -0.0027806   0.08438783]
#
# 🎬 TurnID: 33
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 34
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.82482521 0.06705414 0.12214457]
#
# 🎬 TurnID: 35
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.71085033 -0.10398346  0.18047565]
#
# 🎬 TurnID: 36
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 37
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.98426418 -0.10118017  0.09797495]
#
# 🎬 TurnID: 38
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.87541979 -0.01683251  0.1316583 ]
#
# 🎬 TurnID: 39
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.74444941 0.00507727 0.03642538]
#
# 🎬 TurnID: 40
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.67578279 -0.12855122 -0.00244255]
#
# 🎬 TurnID: 41
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 42
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.97884485 -0.02134067  0.15338728]
#
# 🎬 TurnID: 43
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.14900129 -0.0942879   0.16869989]
#
# 🎬 TurnID: 44
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 45
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.98938284 -0.00499948  0.13456831]
#
# 🎬 TurnID: 46
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 47
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.02113057 -0.08884211  0.17169958]
#
# 🎬 TurnID: 48
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 49
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.89342435 0.12341136 0.16234545]
#
# 🎬 TurnID: 50
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 51
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.95934731 -0.0223131   0.17026127]
#
# 🎬 TurnID: 52
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 53
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.8165786  -0.08042876  0.13535926]
#
# 🎬 TurnID: 54
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.83431128 -0.07797199  0.1269943 ]
#
# 🎬 TurnID: 55
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.93692945 -0.05476125  0.16019184]
#
# 🎬 TurnID: 56
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 57
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.92646658 -0.00910933  0.19894944]
#
# 🎬 TurnID: 58
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 59
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.9248116  0.01010917 0.1527509 ]
#
# 🎬 TurnID: 60
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.88213996 -0.21827332  0.15229308]
#
# 🎬 TurnID: 61
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.59254694 -0.07980389  0.02628735]
#
# 🎬 TurnID: 62
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.5322299  0.01541802 0.17103076]
#
# 🎬 TurnID: 63
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.86383921 -0.1142404   0.08561746]
#
# 🎬 TurnID: 64
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 65
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.82462138 -0.12242638  0.09396903]
#
# 🎬 TurnID: 66
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 67
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.91944419 0.00612044 0.17497087]
#
# 🎬 TurnID: 68
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 69
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.95357384 -0.05279594  0.1317358 ]
#
# 🎬 TurnID: 70
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 71
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.94612897 -0.0732292   0.13870269]
#
# 🎬 TurnID: 72
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 73
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.26002738 -0.19336988  0.18660883]
#
# 🎬 TurnID: 74
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.57577496 -0.11952279 -0.02606609]
#
# 🎬 TurnID: 75
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.3968975  0.01422145 0.17547004]
#
# 🎬 TurnID: 76
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.79652663 -0.06269877  0.09182415]
#
# 🎬 TurnID: 77
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 78
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.95379731 0.02953078 0.09113874]
#
# 🎬 TurnID: 79
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.71458643 -0.096131   -0.07470752]
#
# 🎬 TurnID: 80
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.91303572 -0.14407538  0.14940088]
#
# 🎬 TurnID: 81
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 82
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.81038423 -0.11654945  0.20475082]
#
# 🎬 TurnID: 83
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.67413521 -0.13119461  0.3638269 ]
#
# 🎬 TurnID: 84
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.7170063  0.01325765 0.12803184]
#
# 🎬 TurnID: 85
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 86
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.83103542 -0.04222742  0.16507389]
#
# 🎬 TurnID: 87
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.97587942 -0.06368776  0.09122029]
#
# 🎬 TurnID: 88
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 89
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.99162384 -0.01425487  0.15113761]
#
# 🎬 TurnID: 90
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 91
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [1.09594498 0.0511037  0.18552277]
#
# 🎬 TurnID: 92
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 93
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.23108697 -0.11333141  0.16523151]
#
# 🎬 TurnID: 94
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 95
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.94761729 0.03891293 0.14058424]
#
# 🎬 TurnID: 96
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.67089133 -0.06880738  0.12354733]
#
# 🎬 TurnID: 97
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.12930905 -0.02500806  0.20820388]
#
# 🎬 TurnID: 98
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.80776746 -0.11358913  0.15738191]
#
# 🎬 TurnID: 99
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.97712964 0.01795706 0.18202833]
#
# 🎬 TurnID: 100
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 101
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.99098888 -0.03655033  0.15479006]
#
# 🎬 TurnID: 102
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.68072099 -0.20158911 -0.1347758 ]
#
# 🎬 TurnID: 103
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.3968975  0.01422145 0.17547004]
#
# 🎬 TurnID: 104
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.64304272 -0.10201953  0.16418643]
#
# 🎬 TurnID: 105
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 106
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.37013751 0.04982219 0.29984231]
#
# 🎬 TurnID: 107
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.93188268 -0.09573341  0.18112211]
#
# 🎬 TurnID: 108
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 109
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.72021202 -0.1778744  -0.04764903]
#
# 🎬 TurnID: 110
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.9984094  -0.20413089  0.037654  ]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 2.078561988950926
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.384567623822962
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 1.6412618425676375
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 3.2956316162297417
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 4.016821759998903
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 2.073033155350351
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 1.30706589614077
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 1.8186337829774903
# 📏 Mahalanobis distance between Turn 9 and Turn 10: 2.6505159997716983
# 📏 Mahalanobis distance between Turn 10 and Turn 11: 2.5250965506854537
# 📏 Mahalanobis distance between Turn 11 and Turn 12: 2.5250965506854537
# 📏 Mahalanobis distance between Turn 12 and Turn 13: 2.8423238546653846
# 📏 Mahalanobis distance between Turn 13 and Turn 14: 1.9330107247778656
# 📏 Mahalanobis distance between Turn 14 and Turn 15: 3.162857319296699
# 📏 Mahalanobis distance between Turn 15 and Turn 16: 3.162857319296699
# 📏 Mahalanobis distance between Turn 16 and Turn 17: 1.4394348734461035
# 📏 Mahalanobis distance between Turn 17 and Turn 18: 1.4394348734461035
# 📏 Mahalanobis distance between Turn 18 and Turn 19: 2.1332680370307147
# 📏 Mahalanobis distance between Turn 19 and Turn 20: 3.0551468488868916
# 📏 Mahalanobis distance between Turn 20 and Turn 21: 3.1782260128686257
# 📏 Mahalanobis distance between Turn 21 and Turn 22: 2.386830315667192
# 📏 Mahalanobis distance between Turn 22 and Turn 23: 2.433022179960357
# 📏 Mahalanobis distance between Turn 23 and Turn 24: 3.074516715172507
# 📏 Mahalanobis distance between Turn 24 and Turn 25: 2.8463564948024973
# 📏 Mahalanobis distance between Turn 25 and Turn 26: 2.075117094398341
# 📏 Mahalanobis distance between Turn 26 and Turn 27: 2.026021801058271
# 📏 Mahalanobis distance between Turn 27 and Turn 28: 2.026021801058271
# 📏 Mahalanobis distance between Turn 28 and Turn 29: 2.317833301027411
# 📏 Mahalanobis distance between Turn 29 and Turn 30: 3.128550531666598
# 📏 Mahalanobis distance between Turn 30 and Turn 31: 3.0429812539115617
# 📏 Mahalanobis distance between Turn 31 and Turn 32: 0.9696856350071172
# 📏 Mahalanobis distance between Turn 32 and Turn 33: 4.140699512157698
# 📏 Mahalanobis distance between Turn 33 and Turn 34: 4.230242826352993
# 📏 Mahalanobis distance between Turn 34 and Turn 35: 3.72410001637613
# 📏 Mahalanobis distance between Turn 35 and Turn 36: 2.0684353805113638
# 📏 Mahalanobis distance between Turn 36 and Turn 37: 1.4648342004052939
# 📏 Mahalanobis distance between Turn 37 and Turn 38: 1.0022624459621747
# 📏 Mahalanobis distance between Turn 38 and Turn 39: 1.5599913182817349
# 📏 Mahalanobis distance between Turn 39 and Turn 40: 1.9218136771175245
# 📏 Mahalanobis distance between Turn 40 and Turn 41: 0.6724453163949834
# 📏 Mahalanobis distance between Turn 41 and Turn 42: 2.0096762920640487
# 📏 Mahalanobis distance between Turn 42 and Turn 43: 1.3470158784386814
# 📏 Mahalanobis distance between Turn 43 and Turn 44: 2.3321454689870307
# 📏 Mahalanobis distance between Turn 44 and Turn 45: 2.209995173528382
# 📏 Mahalanobis distance between Turn 45 and Turn 46: 2.209995173528382
# 📏 Mahalanobis distance between Turn 46 and Turn 47: 2.0245647830535245
# 📏 Mahalanobis distance between Turn 47 and Turn 48: 2.0245647830535245
# 📏 Mahalanobis distance between Turn 48 and Turn 49: 3.534831082593577
# 📏 Mahalanobis distance between Turn 49 and Turn 50: 3.534831082593577
# 📏 Mahalanobis distance between Turn 50 and Turn 51: 1.9802963779040192
# 📏 Mahalanobis distance between Turn 51 and Turn 52: 4.209286496381896
# 📏 Mahalanobis distance between Turn 52 and Turn 53: 3.9087184865420257
# 📏 Mahalanobis distance between Turn 53 and Turn 54: 0.1887193076050232
# 📏 Mahalanobis distance between Turn 54 and Turn 55: 0.5289225882622645
# 📏 Mahalanobis distance between Turn 55 and Turn 56: 2.627781190539262
# 📏 Mahalanobis distance between Turn 56 and Turn 57: 2.87643634454055
# 📏 Mahalanobis distance between Turn 57 and Turn 58: 2.87643634454055
# 📏 Mahalanobis distance between Turn 58 and Turn 59: 2.907526740625094
# 📏 Mahalanobis distance between Turn 59 and Turn 60: 3.8502541582953875
# 📏 Mahalanobis distance between Turn 60 and Turn 61: 3.660976036864927
# 📏 Mahalanobis distance between Turn 61 and Turn 62: 1.1496200793626685
# 📏 Mahalanobis distance between Turn 62 and Turn 63: 1.6733157605948636
# 📏 Mahalanobis distance between Turn 63 and Turn 64: 1.0847389926016378
# 📏 Mahalanobis distance between Turn 64 and Turn 65: 1.1289499512594636
# 📏 Mahalanobis distance between Turn 65 and Turn 66: 1.1289499512594636
# 📏 Mahalanobis distance between Turn 66 and Turn 67: 2.100745565040454
# 📏 Mahalanobis distance between Turn 67 and Turn 68: 2.100745565040454
# 📏 Mahalanobis distance between Turn 68 and Turn 69: 1.6977348142630324
# 📏 Mahalanobis distance between Turn 69 and Turn 70: 2.5885794466049417
# 📏 Mahalanobis distance between Turn 70 and Turn 71: 2.528807414946848
# 📏 Mahalanobis distance between Turn 71 and Turn 72: 1.6225004479722889
# 📏 Mahalanobis distance between Turn 72 and Turn 73: 3.3468244800807803
# 📏 Mahalanobis distance between Turn 73 and Turn 74: 4.25337735155429
# 📏 Mahalanobis distance between Turn 74 and Turn 75: 1.742287359189658
# 📏 Mahalanobis distance between Turn 75 and Turn 76: 1.7966238593679993
# 📏 Mahalanobis distance between Turn 76 and Turn 77: 3.913746107138005
# 📏 Mahalanobis distance between Turn 77 and Turn 78: 4.739048812739775
# 📏 Mahalanobis distance between Turn 78 and Turn 79: 1.7317141662589566
# 📏 Mahalanobis distance between Turn 79 and Turn 80: 3.615223536805273
# 📏 Mahalanobis distance between Turn 80 and Turn 81: 4.559517261607683
# 📏 Mahalanobis distance between Turn 81 and Turn 82: 4.228310618920968
# 📏 Mahalanobis distance between Turn 82 and Turn 83: 2.619979144033725
# 📏 Mahalanobis distance between Turn 83 and Turn 84: 5.454112533645108
# 📏 Mahalanobis distance between Turn 84 and Turn 85: 1.9356621520680506
# 📏 Mahalanobis distance between Turn 85 and Turn 86: 1.6501194584562775
# 📏 Mahalanobis distance between Turn 86 and Turn 87: 1.0766483302445375
# 📏 Mahalanobis distance between Turn 87 and Turn 88: 1.666401936997827
# 📏 Mahalanobis distance between Turn 88 and Turn 89: 2.1018083548845117
# 📏 Mahalanobis distance between Turn 89 and Turn 90: 2.1018083548845117
# 📏 Mahalanobis distance between Turn 90 and Turn 91: 2.987274570613792
# 📏 Mahalanobis distance between Turn 91 and Turn 92: 2.987274570613792
# 📏 Mahalanobis distance between Turn 92 and Turn 93: 2.587352579262479
# 📏 Mahalanobis distance between Turn 93 and Turn 94: 3.5995785418585258
# 📏 Mahalanobis distance between Turn 94 and Turn 95: 3.273014559019921
# 📏 Mahalanobis distance between Turn 95 and Turn 96: 2.3140317254126517
# 📏 Mahalanobis distance between Turn 96 and Turn 97: 2.0855718086897066
# 📏 Mahalanobis distance between Turn 97 and Turn 98: 1.9597640729497015
# 📏 Mahalanobis distance between Turn 98 and Turn 99: 2.2726573199870694
# 📏 Mahalanobis distance between Turn 99 and Turn 100: 3.1342551006115245
# 📏 Mahalanobis distance between Turn 100 and Turn 101: 2.8352814327634164
# 📏 Mahalanobis distance between Turn 101 and Turn 102: 2.611595924391451
# 📏 Mahalanobis distance between Turn 102 and Turn 103: 2.671914147442618
# 📏 Mahalanobis distance between Turn 103 and Turn 104: 1.7717389959179695
# 📏 Mahalanobis distance between Turn 104 and Turn 105: 3.593703129948818
# 📏 Mahalanobis distance between Turn 105 and Turn 106: 2.0300448231845567
# 📏 Mahalanobis distance between Turn 106 and Turn 107: 2.5140943784392653
# 📏 Mahalanobis distance between Turn 107 and Turn 108: 2.001464075591961
# 📏 Mahalanobis distance between Turn 108 and Turn 109: 0.3025235147186899
# 📏 Mahalanobis distance between Turn 109 and Turn 110: 1.6795814997245273
#
# 📼 Processing VideoID: kLdBvkC8JEc
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.72104902 0.02056257 0.32426377]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.81842614 -0.04207011  0.19835035]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.87268727 0.05425039 0.21439079]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.8699449  0.00640766 0.18334903]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.73677975 -0.08282104 -0.05231914]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 0.8340534825986571
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.8299286371748327
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 3.0453931788140376
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 3.2268589921908895
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 2.6094422368078627
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 1.9795196529250674
#
# 📼 Processing VideoID: CErmhd_IiM8
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.84607369 0.08312729 0.24178904]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.34408923 0.10718318 0.18783885]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.89946308 0.10800862 0.16211776]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.87993647 0.01948189 0.12774164]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.88235125 0.06239046 0.28308178]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.8899933  -0.13413529  0.01948006]
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.92459494 -0.06776772  0.09174251]
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.87455431 -0.09162993  0.10106909]
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.81276873 -0.01338056  0.08465622]
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.69302257 -0.11106104 -0.04918321]
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.68852526 0.13068251 0.1782312 ]
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.8621796  0.00413943 0.10226715]
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.52055075 -0.03296086  0.05393488]
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.80470983 -0.07455187  0.17240749]
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.85815821 -0.05250718  0.14734363]
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.86843496 0.04742938 0.10634093]
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.7856544  -0.07320509  0.06930735]
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.61917648 -0.08026741  0.17801568]
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.94858565 -0.02237823  0.1221365 ]
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.81562689 0.03502855 0.18618948]
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.8950937  -0.06021974  0.14841235]
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.39713908 0.02075612 0.05587816]
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.82655478 0.03148912 0.22173018]
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.93984447 -0.09600775  0.09194092]
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.93485594 -0.0973345   0.10500701]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 2.5663354486168277
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.9079588157454124
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 1.2323749313684178
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 2.592463414648134
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 3.495148714943602
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 2.6751280827078716
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 0.8336818873827018
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 2.98722685102602
# 📏 Mahalanobis distance between Turn 9 and Turn 10: 2.790618095680203
# 📏 Mahalanobis distance between Turn 10 and Turn 11: 1.5797518398295014
# 📏 Mahalanobis distance between Turn 11 and Turn 12: 1.5847103098022464
# 📏 Mahalanobis distance between Turn 12 and Turn 13: 2.6448125420179203
# 📏 Mahalanobis distance between Turn 13 and Turn 14: 1.3983035409214866
# 📏 Mahalanobis distance between Turn 14 and Turn 15: 1.8830556504403295
# 📏 Mahalanobis distance between Turn 15 and Turn 16: 2.728563675769225
# 📏 Mahalanobis distance between Turn 16 and Turn 17: 4.032168667391083
# 📏 Mahalanobis distance between Turn 17 and Turn 18: 4.210130659654266
# 📏 Mahalanobis distance between Turn 18 and Turn 19: 2.422846209787406
# 📏 Mahalanobis distance between Turn 19 and Turn 20: 1.9219847529910756
# 📏 Mahalanobis distance between Turn 20 and Turn 21: 2.251456692327381
# 📏 Mahalanobis distance between Turn 21 and Turn 22: 2.8354261650797574
# 📏 Mahalanobis distance between Turn 22 and Turn 23: 0.8129816644098445
# 📏 Mahalanobis distance between Turn 23 and Turn 24: 1.1814409956632144
# 📏 Mahalanobis distance between Turn 24 and Turn 25: 3.2960367393465324
# 📏 Mahalanobis distance between Turn 25 and Turn 26: 3.181286593276977
# 📏 Mahalanobis distance between Turn 26 and Turn 27: 1.3694058641709212
# 📏 Mahalanobis distance between Turn 27 and Turn 28: 0.24724141609392483
#
# 📼 Processing VideoID: n4UEymS4kug
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.89994586 0.06696316 0.22400998]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.84773493 -0.02461018  0.15280877]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.93424843 -0.03638304  0.09031797]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.57425954 -0.06255391  0.02010758]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 1.4776205038310208
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.037479289185662
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 2.6961142704181875
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 2.7605584843942217
#
# 📼 Processing VideoID: n_Si2noPLh8
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.7907855  -0.07458357  0.05444177]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.93129574 -0.03658099  0.14640248]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.52417363 -0.205979   -0.08885262]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
# ...
# 📏 Mahalanobis distance between Turn 66 and Turn 67: 2.878218288787688
# 📏 Mahalanobis distance between Turn 67 and Turn 68: 2.6523255035820843
# 📏 Mahalanobis distance between Turn 68 and Turn 69: 3.2509488384814658
# 📏 Mahalanobis distance between Turn 69 and Turn 70: 2.0037736503879238
# 📏 Mahalanobis distance between Turn 70 and Turn 71: 2.465126811842923
# 📏 Mahalanobis distance between Turn 71 and Turn 72: 3.7320038496018753
# 📏 Mahalanobis distance between Turn 72 and Turn 73: 3.752975128774165
# 📏 Mahalanobis distance between Turn 73 and Turn 74: 3.892606568468497
# 📏 Mahalanobis distance between Turn 74 and Turn 75: 3.7806457517990117
# 📏 Mahalanobis distance between Turn 75 and Turn 76: 2.737543307820264
# 📏 Mahalanobis distance between Turn 76 and Turn 77: 2.6008366490830297
# 📏 Mahalanobis distance between Turn 77 and Turn 78: 2.4171620176037942
# 📏 Mahalanobis distance between Turn 78 and Turn 79: 2.8002593708649575
# 📏 Mahalanobis distance between Turn 79 and Turn 80: 4.517991139240275
# 📏 Mahalanobis distance between Turn 80 and Turn 81: 3.7118775767990186
# 📏 Mahalanobis distance between Turn 81 and Turn 82: 1.0021254559543389
# 📏 Mahalanobis distance between Turn 82 and Turn 83: 2.4409389225891593
# 📏 Mahalanobis distance between Turn 83 and Turn 84: 3.40852654278873
# 📏 Mahalanobis distance between Turn 84 and Turn 85: 0.7863044190100065
# 📏 Mahalanobis distance between Turn 85 and Turn 86: 1.8713887391218205
# 📏 Mahalanobis distance between Turn 86 and Turn 87: 1.644286260529734
# 📏 Mahalanobis distance between Turn 87 and Turn 88: 2.150164254551672
# 📏 Mahalanobis distance between Turn 88 and Turn 89: 1.488796399462691
# 📏 Mahalanobis distance between Turn 89 and Turn 90: 4.72656487850865
# 📏 Mahalanobis distance between Turn 90 and Turn 91: 5.750780934225958
# 📏 Mahalanobis distance between Turn 91 and Turn 92: 1.7641948683833621
# 📏 Mahalanobis distance between Turn 92 and Turn 93: 2.304836070445065
# 📏 Mahalanobis distance between Turn 93 and Turn 94: 2.2701776547677124
# 📏 Mahalanobis distance between Turn 94 and Turn 95: 2.7079792103536238
# 📏 Mahalanobis distance between Turn 95 and Turn 96: 2.6399127740774295
# 📏 Mahalanobis distance between Turn 96 and Turn 97: 2.54873660286665
# 📏 Mahalanobis distance between Turn 97 and Turn 98: 1.1723921366380607
# 📏 Mahalanobis distance between Turn 98 and Turn 99: 1.7508772763569176
# 📏 Mahalanobis distance between Turn 99 and Turn 100: 1.0479681410850514
# 📏 Mahalanobis distance between Turn 100 and Turn 101: 1.4683214215000409
# 📏 Mahalanobis distance between Turn 101 and Turn 102: 1.9661994772884115
# 📏 Mahalanobis distance between Turn 102 and Turn 103: 0.9823333537935377
# 📏 Mahalanobis distance between Turn 103 and Turn 104: 2.656941251979761
# 📏 Mahalanobis distance between Turn 104 and Turn 105: 2.9337063614073857
# 📏 Mahalanobis distance between Turn 105 and Turn 106: 2.564531556135757
# 📏 Mahalanobis distance between Turn 106 and Turn 107: 0.3639568402532848
# 📏 Mahalanobis distance between Turn 107 and Turn 108: 2.469924229042388
# 📏 Mahalanobis distance between Turn 108 and Turn 109: 2.040079601801862
# 📏 Mahalanobis distance between Turn 109 and Turn 110: 1.9196391444192444
# 📏 Mahalanobis distance between Turn 110 and Turn 111: 1.5668365253585939
# 📏 Mahalanobis distance between Turn 111 and Turn 112: 3.2856751345406803
# 📏 Mahalanobis distance between Turn 112 and Turn 113: 3.306321815714885
#
# 📼 Processing VideoID: tsy20v-gV5I
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.90013694 0.06619178 0.331253  ]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.03971584 -0.10774923  0.23155156]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 1.4142135623730951
#
# 📼 Processing VideoID: sqFF35P1FAU
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.8941148  -0.02531071  0.20443158]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.87054893 0.04851578 0.09191793]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.91561732 -0.02518705  0.12939356]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.95797259 0.02642036 0.21051357]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [1.04184782 0.03270022 0.28303751]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.91845442 -0.0109201   0.2908599 ]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.02700962 -0.2227861   0.02984852]
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.71886902 -0.1487588   0.01387964]
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.15784158 -0.02136591  0.18099951]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 2.6048522823915654
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 1.5542594685700548
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 0.8064540029146275
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 0.9897277527524428
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 1.5029833748207364
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 3.344312566145183
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 2.766800524443008
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 3.701624152760377
#
# 📼 Processing VideoID: 9b-zJjmG8w8
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.91071784 0.08127294 0.3090844 ]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.92173549 -0.04146443  0.22534913]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.82131591 -0.10475599  0.08787041]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.84513377 -0.01263257  0.21207029]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.81922728 0.02422593 0.17983624]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.03208319 0.22101438 0.39327193]
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.63640239 0.01771729 0.11555231]
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [9.85878996e-01 7.21572979e-04 3.43319931e-01]
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.74342014 -0.13322298  0.14995786]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 1.5931191872837154
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 2.6664343167333233
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 2.6863222308878254
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 1.1137681971461741
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 1.2071107602535538
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 2.813116123536571
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 2.7575156921159762
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 2.233357437053317
# 📏 Mahalanobis distance between Turn 9 and Turn 10: 3.624930436770262
# 📏 Mahalanobis distance between Turn 10 and Turn 11: 2.332280218874349
#
# 📼 Processing VideoID: NYbcSl1rX0A
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.77851359 -0.05167146  0.24755439]
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.82166782 -0.11332915  0.01253359]
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.24934669 -0.02505037  0.01610661]
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.87568176 -0.02791861  0.18688286]
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.54605619 -0.29241138 -0.07820447]
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.88535332 0.01153213 0.13710185]
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.83496495 0.03875692 0.27974995]
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.86742903 -0.12430222  0.14178772]
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.8663139  -0.08927081  0.16550251]
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.90860823 0.01704886 0.26435211]
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.79690184 0.11189507 0.20800636]
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.92732461 -0.08554719  0.22683255]
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.9469     -0.09249297  0.09754168]
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 1.00898052 -0.09747728  0.13768408]
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.54605619 -0.29241138 -0.07820447]
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.82283314 0.01702724 0.23117719]
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.54605619 -0.29241138 -0.07820447]
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.70125559 0.00912269 0.22216168]
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.75280013 -0.12009374 -0.01260938]
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.9139227  -0.1216391   0.10575122]
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.79719896 -0.05905578  0.19853227]
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.653884   -0.24249142 -0.06026817]
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.98650733 0.01095626 0.23067263]
#
# 🎬 TurnID: 29
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.97469735 -0.0412501   0.22213153]
#
# 🎬 TurnID: 30
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.59029138 -0.06090752  0.20714604]
#
# 🎬 TurnID: 31
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.541393   -0.05429377  0.23201126]
#
# 🎬 TurnID: 32
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.85909659 -0.09279308  0.19607871]
#
# 🎬 TurnID: 33
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [0.89012344 0.03116819 0.16882529]
#
# 🎬 TurnID: 34
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 35
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.96409036 -0.08158237  0.04193258]
#
# 🎬 TurnID: 36
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.79358626 0.06599804 0.18414594]
#
# 🎬 TurnID: 37
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 38
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [0.94815692 0.06352011 0.23645518]
#
# 🎬 TurnID: 39
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.006735  -0.0608061  0.084804 ]
#
# 🎬 TurnID: 40
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 41
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 1.08297212 -0.02915501  0.15048531]
#
# 🎬 TurnID: 42
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled AffectR vector: [ 0.76171181 -0.19257147 -0.04233186]
#
# 🎬 TurnID: 43
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled AffectR vector: [ 0.6411953  -0.09563974  0.06539632]
# 📏 Mahalanobis distance between Turn 1 and Turn 2: 3.0647992355173757
# 📏 Mahalanobis distance between Turn 2 and Turn 3: 4.380987883212589
# 📏 Mahalanobis distance between Turn 3 and Turn 4: 4.72231246299695
# 📏 Mahalanobis distance between Turn 4 and Turn 5: 2.859195306151044
# 📏 Mahalanobis distance between Turn 5 and Turn 6: 3.6054929963506606
# 📏 Mahalanobis distance between Turn 6 and Turn 7: 2.0479664060018616
# 📏 Mahalanobis distance between Turn 7 and Turn 8: 2.782598404609179
# 📏 Mahalanobis distance between Turn 8 and Turn 9: 1.8436686801957551
# 📏 Mahalanobis distance between Turn 9 and Turn 10: 1.9778437336424386
# 📏 Mahalanobis distance between Turn 10 and Turn 11: 1.9556434159952745
# 📏 Mahalanobis distance between Turn 11 and Turn 12: 1.0575454614386484
# 📏 Mahalanobis distance between Turn 12 and Turn 13: 2.571823848147047
# 📏 Mahalanobis distance between Turn 13 and Turn 14: 3.229471108977088
# 📏 Mahalanobis distance between Turn 14 and Turn 15: 4.1369795625672525
# 📏 Mahalanobis distance between Turn 15 and Turn 16: 2.052586388183822
# 📏 Mahalanobis distance between Turn 16 and Turn 17: 1.384310430865619
# 📏 Mahalanobis distance between Turn 17 and Turn 18: 1.9540363111215702
# 📏 Mahalanobis distance between Turn 18 and Turn 19: 3.0460047264370753
# 📏 Mahalanobis distance between Turn 19 and Turn 20: 3.1036316244892794
# 📏 Mahalanobis distance between Turn 20 and Turn 21: 3.1036316244892794
# 📏 Mahalanobis distance between Turn 21 and Turn 22: 2.960766062092206
# 📏 Mahalanobis distance between Turn 22 and Turn 23: 2.4434279934904666
# 📏 Mahalanobis distance between Turn 23 and Turn 24: 2.0691899213005587
# 📏 Mahalanobis distance between Turn 24 and Turn 25: 1.5082099083122675
# 📏 Mahalanobis distance between Turn 25 and Turn 26: 2.2532510578771316
# 📏 Mahalanobis distance between Turn 26 and Turn 27: 2.157403352021605
# 📏 Mahalanobis distance between Turn 27 and Turn 28: 2.797105776593728
# 📏 Mahalanobis distance between Turn 28 and Turn 29: 0.876076798922628
# 📏 Mahalanobis distance between Turn 29 and Turn 30: 2.617182982507397
# 📏 Mahalanobis distance between Turn 30 and Turn 31: 0.5222013658776379
# 📏 Mahalanobis distance between Turn 31 and Turn 32: 2.3906065270810166
# 📏 Mahalanobis distance between Turn 32 and Turn 33: 2.746421925185745
# 📏 Mahalanobis distance between Turn 33 and Turn 34: 2.2057170706897726
# 📏 Mahalanobis distance between Turn 34 and Turn 35: 1.5691819575370034
# 📏 Mahalanobis distance between Turn 35 and Turn 36: 2.292500123898919
# 📏 Mahalanobis distance between Turn 36 and Turn 37: 2.6964395545056012
# 📏 Mahalanobis distance between Turn 37 and Turn 38: 2.5383491700003478
# 📏 Mahalanobis distance between Turn 38 and Turn 39: 1.637499943352571
# 📏 Mahalanobis distance between Turn 39 and Turn 40: 1.7509033050827287
# 📏 Mahalanobis distance between Turn 40 and Turn 41: 2.2193516070279533
# 📏 Mahalanobis distance between Turn 41 and Turn 42: 2.2193516070279533
# 📏 Mahalanobis distance between Turn 42 and Turn 43: 1.596021966613632
#
# ✅ Final output shape of distance measurement: (1703, 7)
#        VideoID  turnID    Speaker   3D_Dist  Rationality_Dist  \
# 0  3YxFNCQJXz0       1  Speaker 1       NaN               NaN
# 1  3YxFNCQJXz0       2  Speaker 2  1.899565          0.068287
# 2  3YxFNCQJXz0       3  Speaker 1  1.364950          0.031562
# 3  3YxFNCQJXz0       4  Speaker 2  0.871419          0.034613
# 4  3YxFNCQJXz0       5  Speaker 1  1.173527          0.049777
#
#    Social_Impact_Dist  Valence_Dist
# 0                 NaN           NaN
# 1            0.036051      0.136210
# 2            0.064577      0.035693
# 3            0.039632      0.065932
# 4            0.012239      0.071755

# %%
# Compute cosine distance meaures for BERT word embeddings

def mean_pool_bert_vector(group, speaker):
    """Extract and mean-pool the 1024-d BERT embeddings for the active speaker."""
    cols = [f'BERT_Spkr1_{i}' if speaker == 'Speaker 1' else f'BERT_Spkr2_{i}' for i in range(1024)]
    matrix = group[cols].to_numpy()
    return matrix.mean(axis=0) if len(matrix) > 1 else matrix[0]

def compute_bert_distances(df):
    """Compute cosine distances between BERT embeddings for consecutive turns."""
    results = []

    for vid in df['VideoID'].unique():
        print(f"\n📼 Processing VideoID: {vid}")
        vid_data = df[df['VideoID'] == vid]
        grouped = vid_data.groupby('turnID')

        turn_vectors = []
        turn_ids = []
        speakers = []

        for turn_id, group in grouped:
            speaker = group['Speaker'].iloc[0]
            vector = mean_pool_bert_vector(group, speaker)

            print(f"\n🎬 TurnID: {turn_id}")
            print(f"   🗣️ Active Speaker: {speaker}")
            print(f"   ✅ Mean-pooled BERT vector (dim: {vector.shape}): {vector[:5]}...")

            turn_vectors.append(vector)
            turn_ids.append(turn_id)
            speakers.append(speaker)

        # Compute cosine distances between turns
        bert_dists = [np.nan]
        for i in range(1, len(turn_vectors)):
            d = distance.cosine(turn_vectors[i], turn_vectors[i - 1])
            bert_dists.append(d)
            print(f"📏 BERT cosine distance between Turn {turn_ids[i - 1]} and Turn {turn_ids[i]}: {d}")

        results_df = pd.DataFrame({
            'VideoID': [vid] * len(turn_ids),
            'turnID': turn_ids,
            'Speaker': speakers,
            'BERT_Dist': bert_dists
        })

        results.append(results_df)

    return pd.concat(results, ignore_index=True)

# ✅ Run the function on your word_embeddings DataFrame
bert_dist = compute_bert_distances(word_embeddings)
# Out:
# Streaming output truncated to the last 5000 lines.
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.44409513  0.27576613 -0.69757384 -0.50134343  0.96607256]...
#
# 🎬 TurnID: 104
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.48887336  0.47527048 -0.72809726 -0.56744319  1.02051461]...
#
# 🎬 TurnID: 105
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.05914995  0.23127605 -0.4425548  -0.64224428  0.30802384]...
#
# 🎬 TurnID: 106
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.43453151  0.33578998 -0.63941151 -0.57423699  0.91238803]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.034177772994581246
# 📏 BERT cosine distance between Turn 2 and Turn 3: 0.06492263881606486
# 📏 BERT cosine distance between Turn 3 and Turn 4: 0.06277214736878567
# 📏 BERT cosine distance between Turn 4 and Turn 5: 0.046815748698818216
# 📏 BERT cosine distance between Turn 5 and Turn 6: 0.03215661294143135
# 📏 BERT cosine distance between Turn 6 and Turn 7: 0.03172141101685688
# 📏 BERT cosine distance between Turn 7 and Turn 8: 0.3215086671459858
# 📏 BERT cosine distance between Turn 8 and Turn 9: 0.6282878207437239
# 📏 BERT cosine distance between Turn 9 and Turn 10: 0.1903099240248619
# 📏 BERT cosine distance between Turn 10 and Turn 11: 0.08983002708904153
# 📏 BERT cosine distance between Turn 11 and Turn 12: 0.033735028799849354
# 📏 BERT cosine distance between Turn 12 and Turn 13: 0.019775469242257704
# 📏 BERT cosine distance between Turn 13 and Turn 14: 0.21326302453557722
# 📏 BERT cosine distance between Turn 14 and Turn 15: 0.10263888347962336
# 📏 BERT cosine distance between Turn 15 and Turn 16: 0.10982067108833826
# 📏 BERT cosine distance between Turn 16 and Turn 17: 0.0634688854905342
# 📏 BERT cosine distance between Turn 17 and Turn 18: 0.03795667067172337
# 📏 BERT cosine distance between Turn 18 and Turn 19: 0.03792269645157642
# 📏 BERT cosine distance between Turn 19 and Turn 20: 0.15299207554602334
# 📏 BERT cosine distance between Turn 20 and Turn 21: 0.11432385069001127
# 📏 BERT cosine distance between Turn 21 and Turn 22: 0.08887002306531178
# 📏 BERT cosine distance between Turn 22 and Turn 23: 0.0650953662058914
# 📏 BERT cosine distance between Turn 23 and Turn 24: 0.3459104665572932
# 📏 BERT cosine distance between Turn 24 and Turn 25: 0.38858241970633023
# 📏 BERT cosine distance between Turn 25 and Turn 26: 0.1508688540022195
# 📏 BERT cosine distance between Turn 26 and Turn 27: 0.05924594643330949
# 📏 BERT cosine distance between Turn 27 and Turn 28: 0.0816507771035676
# 📏 BERT cosine distance between Turn 28 and Turn 29: 0.01061630357361898
# 📏 BERT cosine distance between Turn 29 and Turn 30: 0.0530199560663005
# 📏 BERT cosine distance between Turn 30 and Turn 31: 0.04558856182232618
# 📏 BERT cosine distance between Turn 31 and Turn 32: 0.1354994203164045
# 📏 BERT cosine distance between Turn 32 and Turn 33: 0.3545787674973292
# 📏 BERT cosine distance between Turn 33 and Turn 34: 0.09172208991889175
# 📏 BERT cosine distance between Turn 34 and Turn 35: 0.005901655959819507
# 📏 BERT cosine distance between Turn 35 and Turn 36: 0.05466039087056207
# 📏 BERT cosine distance between Turn 36 and Turn 37: 0.05921908685022059
# 📏 BERT cosine distance between Turn 37 and Turn 38: 0.011955780914451486
# 📏 BERT cosine distance between Turn 38 and Turn 39: 0.10273606944564606
# 📏 BERT cosine distance between Turn 39 and Turn 40: 0.022589771352243826
# 📏 BERT cosine distance between Turn 40 and Turn 41: 0.004619501126124637
# 📏 BERT cosine distance between Turn 41 and Turn 42: 0.0072643205590413595
# 📏 BERT cosine distance between Turn 42 and Turn 43: 0.01560267439950147
# 📏 BERT cosine distance between Turn 43 and Turn 44: 0.05235454924896066
# 📏 BERT cosine distance between Turn 44 and Turn 45: 0.028857249102890448
# 📏 BERT cosine distance between Turn 45 and Turn 46: 0.039827254831888426
# 📏 BERT cosine distance between Turn 46 and Turn 47: 0.12218095526445127
# 📏 BERT cosine distance between Turn 47 and Turn 48: 0.08494392291790442
# 📏 BERT cosine distance between Turn 48 and Turn 49: 0.3801116045235473
# 📏 BERT cosine distance between Turn 49 and Turn 50: 0.20583380841133758
# 📏 BERT cosine distance between Turn 50 and Turn 51: 0.2666894372670938
# 📏 BERT cosine distance between Turn 51 and Turn 52: 0.30656365098134697
# 📏 BERT cosine distance between Turn 52 and Turn 53: 0.5546291682247348
# 📏 BERT cosine distance between Turn 53 and Turn 54: 0.017591571499148917
# 📏 BERT cosine distance between Turn 54 and Turn 55: 0.022485422566039026
# 📏 BERT cosine distance between Turn 55 and Turn 56: 0.4342537435640689
# 📏 BERT cosine distance between Turn 56 and Turn 57: 0.36541892214601845
# 📏 BERT cosine distance between Turn 57 and Turn 58: 0.16859650481993227
# 📏 BERT cosine distance between Turn 58 and Turn 59: 0.17705534436562886
# 📏 BERT cosine distance between Turn 59 and Turn 60: 0.03577873047382363
# 📏 BERT cosine distance between Turn 60 and Turn 61: 0.03712179084674494
# 📏 BERT cosine distance between Turn 61 and Turn 62: 0.020515116856444804
# 📏 BERT cosine distance between Turn 62 and Turn 63: 0.028305811310543216
# 📏 BERT cosine distance between Turn 63 and Turn 64: 0.13561829018669913
# 📏 BERT cosine distance between Turn 64 and Turn 65: 0.2428690501319657
# 📏 BERT cosine distance between Turn 65 and Turn 66: 0.1084326688394327
# 📏 BERT cosine distance between Turn 66 and Turn 67: 0.017413260358307148
# 📏 BERT cosine distance between Turn 67 and Turn 68: 0.2161105173528498
# 📏 BERT cosine distance between Turn 68 and Turn 69: 0.11575425969696485
# 📏 BERT cosine distance between Turn 69 and Turn 70: 0.012151806511763064
# 📏 BERT cosine distance between Turn 70 and Turn 71: 0.0788514890666745
# 📏 BERT cosine distance between Turn 71 and Turn 72: 0.11714551621242775
# 📏 BERT cosine distance between Turn 72 and Turn 73: 0.010256488826294596
# 📏 BERT cosine distance between Turn 73 and Turn 74: 0.1418903983120987
# 📏 BERT cosine distance between Turn 74 and Turn 75: 0.6444494806474675
# 📏 BERT cosine distance between Turn 75 and Turn 76: 0.981103473835117
# 📏 BERT cosine distance between Turn 76 and Turn 77: 0.1241368148012072
# 📏 BERT cosine distance between Turn 77 and Turn 78: 0.06433166737813856
# 📏 BERT cosine distance between Turn 78 and Turn 79: 0.011720778421776323
# 📏 BERT cosine distance between Turn 79 and Turn 80: 0.10026827150733708
# 📏 BERT cosine distance between Turn 80 and Turn 81: 0.03501797529789863
# 📏 BERT cosine distance between Turn 81 and Turn 82: 0.019960891130007652
# 📏 BERT cosine distance between Turn 82 and Turn 83: 0.04194576370239045
# 📏 BERT cosine distance between Turn 83 and Turn 84: 0.021802209121913885
# 📏 BERT cosine distance between Turn 84 and Turn 85: 0.05106691749798942
# 📏 BERT cosine distance between Turn 85 and Turn 86: 0.00974819693571971
# 📏 BERT cosine distance between Turn 86 and Turn 87: 0.06011570746241768
# 📏 BERT cosine distance between Turn 87 and Turn 88: 0.02627479341458905
# 📏 BERT cosine distance between Turn 88 and Turn 89: 0.02627479341458905
# 📏 BERT cosine distance between Turn 89 and Turn 90: 0.07936638933716045
# 📏 BERT cosine distance between Turn 90 and Turn 91: 0.026610059763440552
# 📏 BERT cosine distance between Turn 91 and Turn 92: 0.013510400040144144
# 📏 BERT cosine distance between Turn 92 and Turn 93: 0.014120122584261652
# 📏 BERT cosine distance between Turn 93 and Turn 94: 0.017542370215686498
# 📏 BERT cosine distance between Turn 94 and Turn 95: 0.06473660096981326
# 📏 BERT cosine distance between Turn 95 and Turn 96: 0.15858970565330033
# 📏 BERT cosine distance between Turn 96 and Turn 97: 0.14388861574168188
# 📏 BERT cosine distance between Turn 97 and Turn 98: 0.012375806217928331
# 📏 BERT cosine distance between Turn 98 and Turn 99: 0.01900002731764905
# 📏 BERT cosine distance between Turn 99 and Turn 100: 0.1780250299792847
# 📏 BERT cosine distance between Turn 100 and Turn 101: 0.17082896949529758
# 📏 BERT cosine distance between Turn 101 and Turn 102: 0.01458399548741729
# 📏 BERT cosine distance between Turn 102 and Turn 103: 0.010114728272321294
# 📏 BERT cosine distance between Turn 103 and Turn 104: 0.015032608190171604
# 📏 BERT cosine distance between Turn 104 and Turn 105: 0.06554640169067694
# 📏 BERT cosine distance between Turn 105 and Turn 106: 0.03552812852532694
#
# 📼 Processing VideoID: s-djtoC8SjQ
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.98334777  0.49264628 -1.00063741 -0.53832179  1.1142714 ]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.39887242  0.51295353 -0.90813073 -0.30586917  0.71087398]...
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.23852445  0.28336871 -0.78074723 -0.45021829  0.37024453]...
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.83672154  0.37981063 -0.73686981 -0.59778017  1.22992635]...
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.44711399  0.20329754 -0.64109993 -0.35260642 -0.16222095]...
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.44401366  0.23777881 -0.70767367 -0.61834204  0.94866157]...
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.42921259  0.20519935 -0.41603494 -0.34406879 -0.18063043]...
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.62909722  0.27638292 -0.99343723 -0.41873756  1.13653004]...
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47584492  0.25389105 -0.73553044 -0.45773947  0.81152356]...
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.19274473  0.22902992 -0.79117167 -0.45106381  0.28701919]...
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.26678169  0.24115551 -0.63561463 -0.54342592  0.57982719]...
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.03238863  0.33755782 -0.47041148 -0.54403573  0.2714282 ]...
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.02031544  0.61998564 -0.92755681 -0.40825042  0.61527067]...
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.22595692  0.30419001 -0.67496574 -0.52980798  0.67304784]...
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52686828  0.32888305 -0.80919403 -0.51780546  0.84748131]...
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.46065441  0.30167195 -0.83700788 -0.49796018  0.93418372]...
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.54494268  0.57983351 -1.21357906 -0.57132018  1.14847839]...
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.23372572  0.45649838 -0.90934872 -0.3969619   0.51818013]...
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.7109611   0.46351606 -0.9561342  -0.48074242  0.98398417]...
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 29
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.67145395  0.42923003 -0.90874422 -0.32118514  0.81166559]...
#
# 🎬 TurnID: 30
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 31
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.61385745  0.4537093  -0.94316304 -0.56770223  0.68495649]...
#
# 🎬 TurnID: 32
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 33
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.20497751  0.50426263 -0.91624534 -0.55926776  0.57424456]...
#
# 🎬 TurnID: 34
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 35
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.07801577  0.32786542 -0.53514129 -0.46706     0.26190424]...
#
# 🎬 TurnID: 36
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.7541759   0.3357574  -0.98779672 -0.47230014  1.14340031]...
#
# 🎬 TurnID: 37
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.74110234  0.18539523 -0.82549733 -0.69550514  1.17712641]...
#
# 🎬 TurnID: 38
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.26824021 -0.0119167  -1.22764337 -0.4858633   0.96300584]...
#
# 🎬 TurnID: 39
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 40
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.35109162  0.52775669 -0.89100456 -0.48322582  0.6612218 ]...
#
# 🎬 TurnID: 41
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 42
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.15347898  0.15265606 -0.40162644 -0.67068404  0.43263486]...
#
# 🎬 TurnID: 43
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 44
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.46557426  0.65862811 -0.8644082   0.0662559   1.32424092]...
#
# 🎬 TurnID: 45
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 46
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.52399105  0.28653103 -0.32900557 -0.46932679 -0.30478251]...
#
# 🎬 TurnID: 47
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 48
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.20835224  0.23712212 -0.37887606 -0.60158169 -0.07993195]...
#
# 🎬 TurnID: 49
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 50
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.36306262  0.34112495 -0.64165324 -0.63034755  0.81960124]...
#
# 🎬 TurnID: 51
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.42876524  0.43749022 -0.71792442 -0.52113569  0.73141181]...
#
# 🎬 TurnID: 52
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.48596025  0.45479187 -1.03587508 -0.39273039  0.50538576]...
#
# 🎬 TurnID: 53
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.62597191  0.27807432 -0.82493567 -0.62838542  1.04958367]...
#
# 🎬 TurnID: 54
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.54275763  0.39506307 -0.79559022 -0.45058441  0.82289183]...
#
# 🎬 TurnID: 55
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.62176627  0.28806469 -0.76436478 -0.5414086   0.91361457]...
#
# 🎬 TurnID: 56
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.35431477  0.59500998 -0.90596074 -0.26437646  0.78266203]...
#
# 🎬 TurnID: 57
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 58
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.16456014  0.35873362 -0.83806443 -0.44030792  0.48759145]...
#
# 🎬 TurnID: 59
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 60
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.15453003  0.30589312 -0.9034791  -0.24575214  0.4960292 ]...
#
# 🎬 TurnID: 61
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 62
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52262604  0.32782394 -0.93561089 -0.56016171  0.91921812]...
#
# 🎬 TurnID: 63
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.10757004  0.25927106 -0.51195812 -0.47059071  0.48914188]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.06640085267908202
# 📏 BERT cosine distance between Turn 2 and Turn 3: 0.09751801176278385
# 📏 BERT cosine distance between Turn 3 and Turn 4: 0.054369736356608245
# 📏 BERT cosine distance between Turn 4 and Turn 5: 0.054369736356608245
# 📏 BERT cosine distance between Turn 5 and Turn 6: 0.018056958809203993
# 📏 BERT cosine distance between Turn 6 and Turn 7: 0.018056958809203993
# 📏 BERT cosine distance between Turn 7 and Turn 8: 0.18108354845041652
# 📏 BERT cosine distance between Turn 8 and Turn 9: 0.11250262542256984
# 📏 BERT cosine distance between Turn 9 and Turn 10: 0.14945255265503665
# 📏 BERT cosine distance between Turn 10 and Turn 11: 0.17677081946205964
# 📏 BERT cosine distance between Turn 11 and Turn 12: 0.010043866960457226
# 📏 BERT cosine distance between Turn 12 and Turn 13: 0.018023562115918712
# 📏 BERT cosine distance between Turn 13 and Turn 14: 0.030473813439654274
# 📏 BERT cosine distance between Turn 14 and Turn 15: 0.07527368307707727
# 📏 BERT cosine distance between Turn 15 and Turn 16: 0.06817579598730716
# 📏 BERT cosine distance between Turn 16 and Turn 17: 0.0495888454336294
# 📏 BERT cosine distance between Turn 17 and Turn 18: 0.0687083454038957
# 📏 BERT cosine distance between Turn 18 and Turn 19: 0.07901811529172043
# 📏 BERT cosine distance between Turn 19 and Turn 20: 0.2056569749741438
# 📏 BERT cosine distance between Turn 20 and Turn 21: 0.14346409807897365
# 📏 BERT cosine distance between Turn 21 and Turn 22: 0.014611428603656607
# 📏 BERT cosine distance between Turn 22 and Turn 23: 0.007835377733075521
# 📏 BERT cosine distance between Turn 23 and Turn 24: 0.057671633326946914
# 📏 BERT cosine distance between Turn 24 and Turn 25: 0.06668849143619204
# 📏 BERT cosine distance between Turn 25 and Turn 26: 0.08832584259738374
# 📏 BERT cosine distance between Turn 26 and Turn 27: 0.03509410533614399
# 📏 BERT cosine distance between Turn 27 and Turn 28: 0.018995031006524332
# 📏 BERT cosine distance between Turn 28 and Turn 29: 0.019539416802675236
# 📏 BERT cosine distance between Turn 29 and Turn 30: 0.019539416802675236
# 📏 BERT cosine distance between Turn 30 and Turn 31: 0.024244922703199556
# 📏 BERT cosine distance between Turn 31 and Turn 32: 0.022811704894809326
# 📏 BERT cosine distance between Turn 32 and Turn 33: 0.04893006255694676
# 📏 BERT cosine distance between Turn 33 and Turn 34: 0.05796105204623869
# 📏 BERT cosine distance between Turn 34 and Turn 35: 0.09210842642576234
# 📏 BERT cosine distance between Turn 35 and Turn 36: 0.09598283723559553
# 📏 BERT cosine distance between Turn 36 and Turn 37: 0.010545483846195913
# 📏 BERT cosine distance between Turn 37 and Turn 38: 0.044945719072159274
# 📏 BERT cosine distance between Turn 38 and Turn 39: 0.02176361719015918
# 📏 BERT cosine distance between Turn 39 and Turn 40: 0.05544805386158791
# 📏 BERT cosine distance between Turn 40 and Turn 41: 0.08943637018538741
# 📏 BERT cosine distance between Turn 41 and Turn 42: 0.06864673359823792
# 📏 BERT cosine distance between Turn 42 and Turn 43: 0.06864673359823792
# 📏 BERT cosine distance between Turn 43 and Turn 44: 0.5086346859232138
# 📏 BERT cosine distance between Turn 44 and Turn 45: 0.432442296868052
# 📏 BERT cosine distance between Turn 45 and Turn 46: 0.1719500765337113
# 📏 BERT cosine distance between Turn 46 and Turn 47: 0.09613708298244017
# 📏 BERT cosine distance between Turn 47 and Turn 48: 0.038868165160781176
# 📏 BERT cosine distance between Turn 48 and Turn 49: 0.12242734490226559
# 📏 BERT cosine distance between Turn 49 and Turn 50: 0.031157799612905546
# 📏 BERT cosine distance between Turn 50 and Turn 51: 0.008462882225594659
# 📏 BERT cosine distance between Turn 51 and Turn 52: 0.024408382002068074
# 📏 BERT cosine distance between Turn 52 and Turn 53: 0.05396292517587942
# 📏 BERT cosine distance between Turn 53 and Turn 54: 0.03520192935907407
# 📏 BERT cosine distance between Turn 54 and Turn 55: 0.0076843337725271965
# 📏 BERT cosine distance between Turn 55 and Turn 56: 0.17632231595679404
# 📏 BERT cosine distance between Turn 56 and Turn 57: 0.23615590436139755
# 📏 BERT cosine distance between Turn 57 and Turn 58: 0.06261350257358966
# 📏 BERT cosine distance between Turn 58 and Turn 59: 0.04478084963175166
# 📏 BERT cosine distance between Turn 59 and Turn 60: 0.033886434339225335
# 📏 BERT cosine distance between Turn 60 and Turn 61: 0.036021073906976286
# 📏 BERT cosine distance between Turn 61 and Turn 62: 0.012471155519804378
# 📏 BERT cosine distance between Turn 62 and Turn 63: 0.03514522415143284
#
# 📼 Processing VideoID: mVRMa5MAqGo
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.73665732  0.62990361 -1.06772935 -0.32941493  1.16667712]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.74235308  0.45829055 -0.96368468 -0.3489143   1.03535879]...
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.68981755  0.26013348 -0.87910616 -0.43476623  0.94302565]...
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.86949682  0.59756279 -1.08338904 -0.46888804  1.27647424]...
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19068518  0.42138048 -0.80217429 -0.37996743  0.63745918]...
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.10959174  0.46550766 -0.6969229  -0.47892189  0.19668175]...
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.10002667  0.41150846 -0.52090716 -0.16077415  0.3203442 ]...
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.4509007   0.4101139  -0.79648137 -0.30501133  0.82154638]...
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.98520505  0.6758579  -0.95866424 -0.39016011  1.28319418]...
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.12396389  0.58273143 -0.86503536 -0.42813736  0.66478366]...
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.87214398  0.4390752  -1.02726853  0.25393355  1.5994091 ]...
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.8238939   0.43713632 -0.99304646 -0.48172691  1.30046344]...
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.14342263  0.48744839 -0.7564081  -0.51026958  0.72566175]...
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.71423286  0.56873494 -1.09893024 -0.45844728  0.94647753]...
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 29
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.07283585  0.33087471 -0.65057313 -0.43782696  0.41750941]...
#
# 🎬 TurnID: 30
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 31
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.23662502  0.30281731 -0.72755498 -0.49994239  0.6794706 ]...
#
# 🎬 TurnID: 32
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.54104692  0.38550165 -0.90170425 -0.64801711  0.93928981]...
#
# 🎬 TurnID: 33
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 34
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.13155919  0.20636682 -0.70420867 -0.49458462  0.5654515 ]...
#
# 🎬 TurnID: 35
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52244186  0.40542173 -1.06690085 -0.38068354  1.05940974]...
#
# 🎬 TurnID: 36
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 37
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.9579553   0.53250581 -1.03387702 -0.31839699  1.15174639]...
#
# 🎬 TurnID: 38
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.02873763  0.40491474 -0.57149619 -0.50476187  0.44337133]...
#
# 🎬 TurnID: 39
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.08051211  0.27188471 -0.48882174 -0.57624584  0.4809207 ]...
#
# 🎬 TurnID: 40
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.1874495   0.17062111 -0.72348815 -0.61482882  0.83360559]...
#
# 🎬 TurnID: 41
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 42
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.03338187  0.29074302 -0.95065898  0.03439272  0.60971373]...
#
# 🎬 TurnID: 43
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.77358365  0.51056659 -1.04252744 -0.48871559  0.96399778]...
#
# 🎬 TurnID: 44
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 45
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.43271387  0.73136955 -1.14702547 -0.2486773   0.74284071]...
#
# 🎬 TurnID: 46
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 47
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.62357742  0.57342285 -0.7609694  -0.54366982  0.95493007]...
#
# 🎬 TurnID: 48
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 49
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.65703076  0.23586357 -0.82657164 -0.54628313  1.05662048]...
#
# 🎬 TurnID: 50
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 51
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19450817  0.53774554 -1.00975561 -0.22988631  0.76457494]...
#
# 🎬 TurnID: 52
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 53
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.07798424  0.29127118 -0.59558493 -0.13959081  0.50069803]...
#
# 🎬 TurnID: 54
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.56088811  0.67557412 -0.95407057 -0.54219776  1.09572184]...
#
# 🎬 TurnID: 55
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.73374945  0.5953272  -1.32058656 -0.33010489  1.19535518]...
#
# 🎬 TurnID: 56
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 57
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.49700817  0.36621344 -1.42873561 -0.48918349  0.80047452]...
#
# 🎬 TurnID: 58
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 59
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.38101065  0.34242994 -0.94556671 -0.4238829   0.5230028 ]...
#
# 🎬 TurnID: 60
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.80782443  0.39634132 -0.94885659 -0.75714988  1.34715807]...
#
# 🎬 TurnID: 61
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.1296055   0.18523186 -0.55773276 -0.51586765  0.65778434]...
#
# 🎬 TurnID: 62
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.4284611   0.33713627 -0.86415553 -0.48538622  0.97485107]...
#
# 🎬 TurnID: 63
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.25548926  0.34228235 -0.92108411 -0.41829914  0.50996131]...
#
# 🎬 TurnID: 64
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 65
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.36626184  0.33057246 -0.82926053 -0.53239083  0.70555216]...
#
# 🎬 TurnID: 66
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 67
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.49937344  0.45324966 -0.84751976 -0.50618452  0.73631918]...
#
# 🎬 TurnID: 68
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 69
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.29862317  0.411861   -1.08313882 -0.34901968  0.74089092]...
#
# 🎬 TurnID: 70
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 71
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.13591875  0.41117015 -0.72613192 -0.36223218  0.19993921]...
#
# 🎬 TurnID: 72
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 73
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52733833  0.32351685 -0.68785995 -0.48270983  0.7481879 ]...
#
# 🎬 TurnID: 74
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.07332907  0.20147748 -0.6883499  -0.46979332  0.55010581]...
#
# 🎬 TurnID: 75
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.46297297  0.29825777 -0.985632   -0.60323721  1.07085109]...
#
# 🎬 TurnID: 76
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.86959767  0.11151246 -0.09053271 -0.33528098 -0.69001627]...
#
# 🎬 TurnID: 77
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 78
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.76048166  0.06116222 -0.24220662 -0.60860574 -0.4123939 ]...
#
# 🎬 TurnID: 79
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.40732229  0.22385481 -0.37499139 -0.5170027  -0.0593335 ]...
#
# 🎬 TurnID: 80
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.57635367  0.38132137 -1.04316342 -0.67143399  0.97202539]...
#
# 🎬 TurnID: 81
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 82
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.16018526  0.23433605 -0.50745124 -0.40284103  0.06467202]...
#
# 🎬 TurnID: 83
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.39526886  0.15757199 -0.88491786 -0.5500387   0.87795287]...
#
# 🎬 TurnID: 84
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.11822565  0.37481946 -0.82012635 -0.45498505  0.41860217]...
#
# 🎬 TurnID: 85
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 86
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.51547444  0.14851704 -0.42324993 -0.40920103 -0.38635096]...
#
# 🎬 TurnID: 87
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.42364553  0.61273336 -1.25609767 -0.37259007  0.94400656]...
#
# 🎬 TurnID: 88
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 89
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.03794779  0.68676394 -0.85429949 -0.40024194  0.5405342 ]...
#
# 🎬 TurnID: 90
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 91
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-1.11766279  0.63918018 -1.05786622 -0.56498975  1.3118186 ]...
#
# 🎬 TurnID: 92
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 93
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.58928752  0.5555144  -1.19427896 -0.46270728  0.89892566]...
#
# 🎬 TurnID: 94
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 95
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.43329993  0.42941216 -0.63935834 -0.51799548 -0.16128436]...
#
# 🎬 TurnID: 96
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.40080383  0.24927054 -0.88027352 -0.52680385  0.86538875]...
#
# 🎬 TurnID: 97
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47631374  0.36099434 -0.89491236 -0.31958473  0.79031992]...
#
# 🎬 TurnID: 98
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.78931463  0.23298907 -0.86880702 -0.63632524  1.17018282]...
#
# 🎬 TurnID: 99
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.6654489   0.42988247 -1.04815388 -0.46713573  1.03845417]...
#
# 🎬 TurnID: 100
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.19436641  0.41167271 -0.67165881 -0.48154294  0.5431689 ]...
#
# 🎬 TurnID: 101
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.93012631  0.3689099  -1.24610138 -0.46383566  1.24110782]...
#
# 🎬 TurnID: 102
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.29846662  0.1391685  -0.5680899  -0.5948559   0.71672279]...
#
# 🎬 TurnID: 103
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.46297297  0.29825777 -0.985632   -0.60323721  1.07085109]...
#
# 🎬 TurnID: 104
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.93106663  0.30413517 -0.99201357 -0.62556684  1.18303907]...
#
# 🎬 TurnID: 105
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 106
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.50364035  0.34514797 -0.857261   -0.5145334   0.90341461]...
#
# 🎬 TurnID: 107
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.59950799  0.32441661 -0.8551299  -0.21696299  1.38051975]...
#
# 🎬 TurnID: 108
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 109
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.13891861  0.3548193  -0.57239759 -0.48598558  0.48740548]...
#
# 🎬 TurnID: 110
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.17489702  0.24597059 -1.09933591 -0.57784158  0.88957447]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.10978286661109737
# 📏 BERT cosine distance between Turn 2 and Turn 3: 0.062446630136306136
# 📏 BERT cosine distance between Turn 3 and Turn 4: 0.04093348728858637
# 📏 BERT cosine distance between Turn 4 and Turn 5: 0.01309875010012762
# 📏 BERT cosine distance between Turn 5 and Turn 6: 0.023972153357297965
# 📏 BERT cosine distance between Turn 6 and Turn 7: 0.07575843312112485
# 📏 BERT cosine distance between Turn 7 and Turn 8: 0.03198705186397288
# 📏 BERT cosine distance between Turn 8 and Turn 9: 0.06844128074720379
# 📏 BERT cosine distance between Turn 9 and Turn 10: 0.055109704585110775
# 📏 BERT cosine distance between Turn 10 and Turn 11: 0.03618764549428799
# 📏 BERT cosine distance between Turn 11 and Turn 12: 0.03618764549428799
# 📏 BERT cosine distance between Turn 12 and Turn 13: 0.3427958222113162
# 📏 BERT cosine distance between Turn 13 and Turn 14: 0.3362343528133256
# 📏 BERT cosine distance between Turn 14 and Turn 15: 0.01934818951724837
# 📏 BERT cosine distance between Turn 15 and Turn 16: 0.01934818951724837
# 📏 BERT cosine distance between Turn 16 and Turn 17: 0.10870466714234517
# 📏 BERT cosine distance between Turn 17 and Turn 18: 0.10870466714234517
# 📏 BERT cosine distance between Turn 18 and Turn 19: 0.09375764859178304
# 📏 BERT cosine distance between Turn 19 and Turn 20: 0.0863459346548816
# 📏 BERT cosine distance between Turn 20 and Turn 21: 0.5178975355308361
# 📏 BERT cosine distance between Turn 21 and Turn 22: 0.4235939963566302
# 📏 BERT cosine distance between Turn 22 and Turn 23: 0.09439705021793232
# 📏 BERT cosine distance between Turn 23 and Turn 24: 0.1458844479364001
# 📏 BERT cosine distance between Turn 24 and Turn 25: 0.12429605547571665
# 📏 BERT cosine distance between Turn 25 and Turn 26: 0.11717497464497195
# 📏 BERT cosine distance between Turn 26 and Turn 27: 0.024493881719105493
# 📏 BERT cosine distance between Turn 27 and Turn 28: 0.024493881719105493
# 📏 BERT cosine distance between Turn 28 and Turn 29: 0.04894089301154758
# 📏 BERT cosine distance between Turn 29 and Turn 30: 0.011004754375133263
# 📏 BERT cosine distance between Turn 30 and Turn 31: 0.006647794915104144
# 📏 BERT cosine distance between Turn 31 and Turn 32: 0.020602033477483905
# 📏 BERT cosine distance between Turn 32 and Turn 33: 0.03674634879963745
# 📏 BERT cosine distance between Turn 33 and Turn 34: 0.04627897079571408
# 📏 BERT cosine distance between Turn 34 and Turn 35: 0.09330458166977273
# 📏 BERT cosine distance between Turn 35 and Turn 36: 0.04515808755269923
# 📏 BERT cosine distance between Turn 36 and Turn 37: 0.025330601305225797
# 📏 BERT cosine distance between Turn 37 and Turn 38: 0.12054762514692963
# 📏 BERT cosine distance between Turn 38 and Turn 39: 0.08678083033377781
# 📏 BERT cosine distance between Turn 39 and Turn 40: 0.011857319463465021
# 📏 BERT cosine distance between Turn 40 and Turn 41: 0.021218375266546907
# 📏 BERT cosine distance between Turn 41 and Turn 42: 0.46222041870540354
# 📏 BERT cosine distance between Turn 42 and Turn 43: 0.4432635622482066
# 📏 BERT cosine distance between Turn 43 and Turn 44: 0.015271051389282753
# 📏 BERT cosine distance between Turn 44 and Turn 45: 0.16894934254947802
# 📏 BERT cosine distance between Turn 45 and Turn 46: 0.16894934254947802
# 📏 BERT cosine distance between Turn 46 and Turn 47: 0.06193132273094104
# 📏 BERT cosine distance between Turn 47 and Turn 48: 0.06193132273094104
# 📏 BERT cosine distance between Turn 48 and Turn 49: 0.016372988950780987
# 📏 BERT cosine distance between Turn 49 and Turn 50: 0.016372988950780987
# 📏 BERT cosine distance between Turn 50 and Turn 51: 0.3877743768225226
# 📏 BERT cosine distance between Turn 51 and Turn 52: 0.46808700473316744
# 📏 BERT cosine distance between Turn 52 and Turn 53: 0.47773459879282376
# 📏 BERT cosine distance between Turn 53 and Turn 54: 0.2531138341488105
# 📏 BERT cosine distance between Turn 54 and Turn 55: 0.10374211496849306
# 📏 BERT cosine distance between Turn 55 and Turn 56: 0.2845508050269836
# 📏 BERT cosine distance between Turn 56 and Turn 57: 0.15277907400484692
# 📏 BERT cosine distance between Turn 57 and Turn 58: 0.15277907400484692
# 📏 BERT cosine distance between Turn 58 and Turn 59: 0.024894361597124326
# 📏 BERT cosine distance between Turn 59 and Turn 60: 0.06704309099441375
# 📏 BERT cosine distance between Turn 60 and Turn 61: 0.08758007706023441
# 📏 BERT cosine distance between Turn 61 and Turn 62: 0.017179270434990346
# 📏 BERT cosine distance between Turn 62 and Turn 63: 0.04039805004303665
# 📏 BERT cosine distance between Turn 63 and Turn 64: 0.04635561630605134
# 📏 BERT cosine distance between Turn 64 and Turn 65: 0.024185902166700135
# 📏 BERT cosine distance between Turn 65 and Turn 66: 0.024185902166700135
# 📏 BERT cosine distance between Turn 66 and Turn 67: 0.022510186201654236
# 📏 BERT cosine distance between Turn 67 and Turn 68: 0.022510186201654236
# 📏 BERT cosine distance between Turn 68 and Turn 69: 0.05437075699641736
# 📏 BERT cosine distance between Turn 69 and Turn 70: 0.06044483709628057
# 📏 BERT cosine distance between Turn 70 and Turn 71: 0.07937122529685992
# 📏 BERT cosine distance between Turn 71 and Turn 72: 0.11164368836009875
# 📏 BERT cosine distance between Turn 72 and Turn 73: 0.0181450456763268
# 📏 BERT cosine distance between Turn 73 and Turn 74: 0.021666636934489336
# 📏 BERT cosine distance between Turn 74 and Turn 75: 0.03418400524331533
# 📏 BERT cosine distance between Turn 75 and Turn 76: 0.30871985355537945
# 📏 BERT cosine distance between Turn 76 and Turn 77: 0.3518239291790709
# 📏 BERT cosine distance between Turn 77 and Turn 78: 0.2905458704884203
# 📏 BERT cosine distance between Turn 78 and Turn 79: 0.024079988680087094
# 📏 BERT cosine distance between Turn 79 and Turn 80: 0.12314349430118943
# 📏 BERT cosine distance between Turn 80 and Turn 81: 0.03951515759007018
# 📏 BERT cosine distance between Turn 81 and Turn 82: 0.1080639705740647
# 📏 BERT cosine distance between Turn 82 and Turn 83: 0.06303761944292097
# 📏 BERT cosine distance between Turn 83 and Turn 84: 0.039936250081490376
# 📏 BERT cosine distance between Turn 84 and Turn 85: 0.056653869662586565
# 📏 BERT cosine distance between Turn 85 and Turn 86: 0.1821910028648952
# 📏 BERT cosine distance between Turn 86 and Turn 87: 0.14803467594563446
# 📏 BERT cosine distance between Turn 87 and Turn 88: 0.08899158862993095
# 📏 BERT cosine distance between Turn 88 and Turn 89: 0.1891948552840751
# 📏 BERT cosine distance between Turn 89 and Turn 90: 0.1891948552840751
# 📏 BERT cosine distance between Turn 90 and Turn 91: 0.08139412842295579
# 📏 BERT cosine distance between Turn 91 and Turn 92: 0.08139412842295579
# 📏 BERT cosine distance between Turn 92 and Turn 93: 0.07998378466958778
# 📏 BERT cosine distance between Turn 93 and Turn 94: 0.10771756370043228
# 📏 BERT cosine distance between Turn 94 and Turn 95: 0.1334302691733884
# 📏 BERT cosine distance between Turn 95 and Turn 96: 0.15672238267439997
# 📏 BERT cosine distance between Turn 96 and Turn 97: 0.037270834171465816
# 📏 BERT cosine distance between Turn 97 and Turn 98: 0.06345944854726038
# 📏 BERT cosine distance between Turn 98 and Turn 99: 0.08964267633169909
# 📏 BERT cosine distance between Turn 99 and Turn 100: 0.08524447856094908
# 📏 BERT cosine distance between Turn 100 and Turn 101: 0.09104580302054677
# 📏 BERT cosine distance between Turn 101 and Turn 102: 0.0837055018989884
# 📏 BERT cosine distance between Turn 102 and Turn 103: 0.02215479782611285
# 📏 BERT cosine distance between Turn 103 and Turn 104: 0.017819915141073617
# 📏 BERT cosine distance between Turn 104 and Turn 105: 0.02154167725341216
# 📏 BERT cosine distance between Turn 105 and Turn 106: 0.016360288256728084
# 📏 BERT cosine distance between Turn 106 and Turn 107: 0.3689650758862205
# 📏 BERT cosine distance between Turn 107 and Turn 108: 0.32271751444886765
# 📏 BERT cosine distance between Turn 108 and Turn 109: 0.05143125392215653
# 📏 BERT cosine distance between Turn 109 and Turn 110: 0.028271835447012172
#
# 📼 Processing VideoID: kLdBvkC8JEc
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.98888087  0.46431106 -1.09148228 -0.64809638  1.24802732]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.08064492  0.202383   -0.5153558  -0.61633381  0.24605536]...
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
# ...
# 📏 BERT cosine distance between Turn 95 and Turn 96: 0.023397288495940693
# 📏 BERT cosine distance between Turn 96 and Turn 97: 0.06148511577664528
# 📏 BERT cosine distance between Turn 97 and Turn 98: 0.06497928419500454
# 📏 BERT cosine distance between Turn 98 and Turn 99: 0.029075066547299744
# 📏 BERT cosine distance between Turn 99 and Turn 100: 0.17432664796585584
# 📏 BERT cosine distance between Turn 100 and Turn 101: 0.12718802200421908
# 📏 BERT cosine distance between Turn 101 and Turn 102: 0.020696104750605238
# 📏 BERT cosine distance between Turn 102 and Turn 103: 0.3964677176451682
# 📏 BERT cosine distance between Turn 103 and Turn 104: 0.3642211582214906
# 📏 BERT cosine distance between Turn 104 and Turn 105: 0.00870589055108495
# 📏 BERT cosine distance between Turn 105 and Turn 106: 0.06425352999176381
# 📏 BERT cosine distance between Turn 106 and Turn 107: 0.07367957676753689
# 📏 BERT cosine distance between Turn 107 and Turn 108: 0.22155700971442083
# 📏 BERT cosine distance between Turn 108 and Turn 109: 0.11191135446053058
# 📏 BERT cosine distance between Turn 109 and Turn 110: 0.08882989218571369
# 📏 BERT cosine distance between Turn 110 and Turn 111: 0.07973782900180815
# 📏 BERT cosine distance between Turn 111 and Turn 112: 0.08048110518958829
# 📏 BERT cosine distance between Turn 112 and Turn 113: 0.11470777159824375
#
# 📼 Processing VideoID: tsy20v-gV5I
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.75394648  0.45911095 -0.8601504  -0.45531666  0.94153005]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.74022841  0.37748212 -0.96332723 -0.50430351  0.96888828]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.025110717033149266
#
# 📼 Processing VideoID: sqFF35P1FAU
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.44872168  0.50042243 -0.9340072  -0.44185716  0.69001028]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.48267147  0.46458918 -0.9878099  -0.32719696  0.64724016]...
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.06082604  0.32010449 -0.73918371 -0.39426979  0.32330588]...
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.53362703  0.31795213 -0.91365445 -0.29099402  0.84932423]...
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.59653038  0.34412447 -0.92105848 -0.43489316  0.79113638]...
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.7766183   0.39563522 -0.95740968 -0.62841606  1.02220488]...
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.61837196  0.24304885 -0.75537908 -0.60116822  1.00983012]...
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.40180454  0.17352538 -0.74125141 -0.55420661  0.87710673]...
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47914132  0.40077528 -0.67749721 -0.41533619  0.78745693]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.01570967656021316
# 📏 BERT cosine distance between Turn 2 and Turn 3: 0.041156233995546576
# 📏 BERT cosine distance between Turn 3 and Turn 4: 0.09849787802305476
# 📏 BERT cosine distance between Turn 4 and Turn 5: 0.005300480309435529
# 📏 BERT cosine distance between Turn 5 and Turn 6: 0.03332470281240929
# 📏 BERT cosine distance between Turn 6 and Turn 7: 0.044018874168765154
# 📏 BERT cosine distance between Turn 7 and Turn 8: 0.00937977827784009
# 📏 BERT cosine distance between Turn 8 and Turn 9: 0.00751210227287058
#
# 📼 Processing VideoID: 9b-zJjmG8w8
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.72335893  0.48724696 -0.89186412 -0.52135015  0.9860062 ]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.30929229  0.4145962  -0.8171894  -0.45252469  0.63561696]...
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.86984873  0.55829787 -0.88871074 -0.78194094  1.34417379]...
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.560709    0.45123172 -0.93291092 -0.48176545  0.86654025]...
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-6.71133399e-04  3.29596572e-01 -6.99857324e-01 -3.64667863e-01
#   3.65000263e-01]...
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.52643621  0.24537805 -0.9449085  -0.44004527  1.2402761 ]...
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.39092138  0.25218275 -0.69990724 -0.4768168   0.74830925]...
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.25328168  0.37344503 -1.09965837 -0.50589275  0.64185113]...
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.51249647  0.33625302 -0.74912429 -0.57707661  0.76517439]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.03262446872175406
# 📏 BERT cosine distance between Turn 2 and Turn 3: 0.10269398377282113
# 📏 BERT cosine distance between Turn 3 and Turn 4: 0.04024056153456168
# 📏 BERT cosine distance between Turn 4 and Turn 5: 0.08072274557562753
# 📏 BERT cosine distance between Turn 5 and Turn 6: 0.1327188954651619
# 📏 BERT cosine distance between Turn 6 and Turn 7: 0.22830026462570863
# 📏 BERT cosine distance between Turn 7 and Turn 8: 0.028127476599410617
# 📏 BERT cosine distance between Turn 8 and Turn 9: 0.021453663274548007
# 📏 BERT cosine distance between Turn 9 and Turn 10: 0.05905674468668798
# 📏 BERT cosine distance between Turn 10 and Turn 11: 0.058543883302823896
#
# 📼 Processing VideoID: NYbcSl1rX0A
#
# 🎬 TurnID: 1
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.42693335  0.48213536 -0.79398447 -0.49611971  0.70889568]...
#
# 🎬 TurnID: 2
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.80885071  0.34191307 -0.91682601 -0.52231252  1.15127504]...
#
# 🎬 TurnID: 3
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.40577886  0.0940576  -0.23154449 -0.55871415 -0.23161511]...
#
# 🎬 TurnID: 4
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.55176896  0.42027369 -0.92772338 -0.38325627  0.85187072]...
#
# 🎬 TurnID: 5
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.22841878  0.34104505 -0.63551593 -0.48415184  0.58768791]...
#
# 🎬 TurnID: 6
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.02614393  0.40517378 -0.34058851 -0.46283925  0.12125715]...
#
# 🎬 TurnID: 7
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.63638991  0.28675348 -1.01846933 -0.69614363  1.0938046 ]...
#
# 🎬 TurnID: 8
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.85019922  0.52443719 -0.89231747 -0.56123424  1.14572847]...
#
# 🎬 TurnID: 9
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.75178647  0.00821452  0.02060597 -0.51067239 -0.73775357]...
#
# 🎬 TurnID: 10
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 11
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.49128011  0.11707497 -1.05178237 -0.56649858  1.02524841]...
#
# 🎬 TurnID: 12
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.67940617  0.40720177 -1.18063641 -0.50402808  1.0730145 ]...
#
# 🎬 TurnID: 13
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 14
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.69413596  0.39460176 -0.89931697 -0.54548466  0.99461907]...
#
# 🎬 TurnID: 15
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.28736022  0.36102718 -0.88750988 -0.4287568   0.73408598]...
#
# 🎬 TurnID: 16
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.21548226  0.3166858  -1.0663619  -0.38938394  0.70877546]...
#
# 🎬 TurnID: 17
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 18
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.43560159  0.52106273 -0.83807969 -0.352862    0.78423649]...
#
# 🎬 TurnID: 19
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.22841878  0.34104505 -0.63551593 -0.48415184  0.58768791]...
#
# 🎬 TurnID: 20
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.93895555  0.61579895 -1.01072204 -0.53444695  1.24198282]...
#
# 🎬 TurnID: 21
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.21467908  0.34221658 -0.69008821 -0.42084458  0.52753478]...
#
# 🎬 TurnID: 22
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [ 0.71015811  0.1874914  -0.19870754 -0.54269236 -0.339757  ]...
#
# 🎬 TurnID: 23
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.82508695  0.24885409 -0.92872131 -0.6223982   1.25065827]...
#
# 🎬 TurnID: 24
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.28228279  0.44214068 -0.84906399 -0.42560716  0.59664543]...
#
# 🎬 TurnID: 25
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 26
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.0790175   0.32159382 -0.67997414 -0.53105402  0.38169003]...
#
# 🎬 TurnID: 27
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.10712123  0.18865874 -0.90793824 -0.47329819  0.70233148]...
#
# 🎬 TurnID: 28
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.65327752  0.4448576  -1.04773569 -0.48553729  1.02290821]...
#
# 🎬 TurnID: 29
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.60902596  0.43400311 -0.9914453  -0.47595087  0.89430302]...
#
# 🎬 TurnID: 30
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.40522787  0.26317638 -0.90161479 -0.42710757  0.75604546]...
#
# 🎬 TurnID: 31
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.2532773   0.16999431 -0.87189496 -0.52454233  0.72687984]...
#
# 🎬 TurnID: 32
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.48506498  0.3060154  -0.76376963 -0.42423877  0.7532236 ]...
#
# 🎬 TurnID: 33
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.23414835  0.16125655 -0.62291032 -0.37896708  0.36413872]...
#
# 🎬 TurnID: 34
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 35
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.3107833   0.36108553 -0.82220459 -0.40332687  0.68388385]...
#
# 🎬 TurnID: 36
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.4097122   0.36769563 -0.62552673 -0.60263008  0.59590095]...
#
# 🎬 TurnID: 37
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.63638991  0.28675348 -1.01846933 -0.69614363  1.0938046 ]...
#
# 🎬 TurnID: 38
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.70022207  0.30170819 -0.86750418 -0.43464622  0.90813059]...
#
# 🎬 TurnID: 39
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.57478487  0.34921479 -0.92755616 -0.52679026  0.66958648]...
#
# 🎬 TurnID: 40
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 41
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.59805405  0.25217721 -0.99273276 -0.51009089  0.78264612]...
#
# 🎬 TurnID: 42
#    🗣️ Active Speaker: Speaker 2
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.47421223  0.21635737 -0.92293924 -0.71935731  1.1309247 ]...
#
# 🎬 TurnID: 43
#    🗣️ Active Speaker: Speaker 1
#    ✅ Mean-pooled BERT vector (dim: (1024,)): [-0.37421721  0.34394857 -0.5905537  -0.64379525  0.70094931]...
# 📏 BERT cosine distance between Turn 1 and Turn 2: 0.10426679571878783
# 📏 BERT cosine distance between Turn 2 and Turn 3: 0.18797291158352003
# 📏 BERT cosine distance between Turn 3 and Turn 4: 0.12319695526584906
# 📏 BERT cosine distance between Turn 4 and Turn 5: 0.017808204783235193
# 📏 BERT cosine distance between Turn 5 and Turn 6: 0.018825297013422393
# 📏 BERT cosine distance between Turn 6 and Turn 7: 0.07595317814649427
# 📏 BERT cosine distance between Turn 7 and Turn 8: 0.052602072779858955
# 📏 BERT cosine distance between Turn 8 and Turn 9: 0.3529363715389745
# 📏 BERT cosine distance between Turn 9 and Turn 10: 0.28834993856369817
# 📏 BERT cosine distance between Turn 10 and Turn 11: 0.01921092596755314
# 📏 BERT cosine distance between Turn 11 and Turn 12: 0.024872055732426568
# 📏 BERT cosine distance between Turn 12 and Turn 13: 0.04213378551461733
# 📏 BERT cosine distance between Turn 13 and Turn 14: 0.019314257003034352
# 📏 BERT cosine distance between Turn 14 and Turn 15: 0.028406796134284762
# 📏 BERT cosine distance between Turn 15 and Turn 16: 0.042268527010334345
# 📏 BERT cosine distance between Turn 16 and Turn 17: 0.02369083645965353
# 📏 BERT cosine distance between Turn 17 and Turn 18: 0.0271239697809601
# 📏 BERT cosine distance between Turn 18 and Turn 19: 0.022962505947275336
# 📏 BERT cosine distance between Turn 19 and Turn 20: 0.08905118939801404
# 📏 BERT cosine distance between Turn 20 and Turn 21: 0.09790945946451346
# 📏 BERT cosine distance between Turn 21 and Turn 22: 0.11333235604178205
# 📏 BERT cosine distance between Turn 22 and Turn 23: 0.2642353294148154
# 📏 BERT cosine distance between Turn 23 and Turn 24: 0.0590463425917398
# 📏 BERT cosine distance between Turn 24 and Turn 25: 0.039970712973291245
# 📏 BERT cosine distance between Turn 25 and Turn 26: 0.048372729413623805
# 📏 BERT cosine distance between Turn 26 and Turn 27: 0.022484659879860924
# 📏 BERT cosine distance between Turn 27 and Turn 28: 0.023553709341985418
# 📏 BERT cosine distance between Turn 28 and Turn 29: 0.0074777295534571575
# 📏 BERT cosine distance between Turn 29 and Turn 30: 0.013850004140949501
# 📏 BERT cosine distance between Turn 30 and Turn 31: 0.006209394184737316
# 📏 BERT cosine distance between Turn 31 and Turn 32: 0.00855186307056599
# 📏 BERT cosine distance between Turn 32 and Turn 33: 0.04997409644363182
# 📏 BERT cosine distance between Turn 33 and Turn 34: 0.07354893336956148
# 📏 BERT cosine distance between Turn 34 and Turn 35: 0.02448431527761341
# 📏 BERT cosine distance between Turn 35 and Turn 36: 0.0181742728421338
# 📏 BERT cosine distance between Turn 36 and Turn 37: 0.07172846320891091
# 📏 BERT cosine distance between Turn 37 and Turn 38: 0.04066816840433707
# 📏 BERT cosine distance between Turn 38 and Turn 39: 0.01816169087945707
# 📏 BERT cosine distance between Turn 39 and Turn 40: 0.016539043032656298
# 📏 BERT cosine distance between Turn 40 and Turn 41: 0.012529406593726033
# 📏 BERT cosine distance between Turn 41 and Turn 42: 0.012529406593726033
# 📏 BERT cosine distance between Turn 42 and Turn 43: 0.029477376100414676

# %%
# Merge affectR_dist and bert_dist_df on VideoID and turnID
turn_distances = pd.merge(affectR_dist, bert_dist, on=['VideoID', 'turnID', 'Speaker'], how='outer')

# Drop duplicate columns if any (e.g., Speaker from both sides)
turn_distances = turn_distances.loc[:, ~turn_distances.columns.duplicated()]

# Define the output file path
output_path = output_dir + 'turn_distance.csv'

# Save the DataFrame to CSV
turn_distances.to_csv(output_path, index=False)

print(f"✅ CSV file successfully saved to: {output_path}")

# Merge combined distances back with the original word_embeddings dataframe
semantic_data = pd.merge(word_embeddings, turn_distances, on=['VideoID', 'turnID'], how='left')

# Drop duplicate columns if any (e.g., Speaker from both sides)
semantic_data = semantic_data.loc[:, ~semantic_data.columns.duplicated()]

# Define the output file path
output_path = output_dir + 'semantic_data.csv'

# Save the DataFrame to CSV
semantic_data.to_csv(output_path, index=False)

print(f"✅ CSV file successfully saved to: {output_path}")
# Out:
# ✅ CSV file successfully saved to: /content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/Outputs/turn_distance.csv
# ✅ CSV file successfully saved to: /content/drive/My Drive/Closeness_Project_Materials/FeaturePipeline/Semantic_Preprocessing/Outputs/semantic_data.csv
